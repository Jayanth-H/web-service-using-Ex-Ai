# %% [markdown]
# #

# %% [markdown]
# # **Website Recommendation System**

# %% [markdown]
# ### Import neccessary libraries

# %%
from sklearn.preprocessing import LabelEncoder
from sklearn.model_selection import train_test_split
from sklearn.metrics import classification_report, accuracy_score, confusion_matrix
import matplotlib.pyplot as plt
import seaborn as sns
import pandas as pd
import numpy as np
import joblib

# %% [markdown]
# # # Data collection

# %%
# Load the dataset
file_path = r'dataset\qws2.csv'
df = pd.read_csv(file_path)

# %% [markdown]
# #### Analys the data

# %%
df
# Out:
#       Response Time   Availability   Throughput   Successability  \
# 0            302.75             89          7.1               90
# 1            482.00             85         16.0               95
# 2           3321.40             89          1.4               96
# 3            126.17             98         12.0              100
# 4            107.00             87          1.9               95
# ...             ...            ...          ...              ...
# 2498         200.80             93          2.4               98
# 2499          56.17             97         11.3               97
# 2500          93.93             80          2.1               80
# 2501         106.75             86          1.3               95
# 2502         316.50             72         15.9               72
#
#        Reliability   Compliance   Best Practices   Latency   Documentation  \
# 0               73           78               80    187.75              32
# 1               73          100               84      1.00               2
# 2               73           78               80      2.60              96
# 3               67           78               82     22.77              89
# 4               73           89               62     58.33              93
# ...            ...          ...              ...       ...             ...
# 2498            73          100               84      7.40              41
# 2499            83           78               91      7.17               3
# 2500            67           78               82      3.72              60
# 2501            80           78               87      1.25              96
# 2502            80           89               87      5.50               8
#
#            Service Name                                       WSDL Address  \
# 0          MAPPMatching  http://xml.assessment.com/service/MAPPMatching...
# 1             Compound2  http://www.mssoapinterop.org/asmx/WSDL/compoun...
# 2              USDAData  http://www.strikeiron.com/webservices/usdadata...
# 3     GBNIRHolidayDates  http://www.holidaywebservice.com/Holidays/GBNI...
# 4              CasUsers  http://galex.stsci.edu/casjobs/CasUsers.asmx?WSDL
# ...                 ...                                                ...
# 2498     garnierService  http://genome.dkfz-heidelberg.de/menu/hobit/em...
# 2499           AWSAlexa   http://awis.amazonaws.com/AWSAlexa/AWSAlexa.wsdl
# 2500           interop2       http://www.cs.fsu.edu/~engelen/interop2.wsdl
# 2501    SailboatCalcsWS  http://pooh.poly.asu.edu/cst556-sailboatcalcsw...
# 2502    Slash/SOAP/Test                 http://use.perl.org/soap/Test.wsdl
#
#      Unnamed: 11
# 0            NaN
# 1            NaN
# 2            NaN
# 3            NaN
# 4            NaN
# ...          ...
# 2498         NaN
# 2499         NaN
# 2500         NaN
# 2501         NaN
# 2502         NaN
#
# [2503 rows x 12 columns]

# %%
# Count rows and columns
df.shape
# Out:
# (2503, 12)

# %%
# columns names
df.columns
# Out:
# Index(['Response Time', ' Availability', ' Throughput', ' Successability',
#        ' Reliability', ' Compliance', ' Best Practices', ' Latency',
#        ' Documentation', ' Service Name', ' WSDL Address', 'Unnamed: 11'],
#       dtype='object')

# %% [markdown]
# ## Dataset Description
#
# ### QWS dataset - Quality Web Service
#
# | ID  | Parameter Name       | Description                                                    | Units              |
# | --- | -------------------- | -------------------------------------------------------------- | ------------------ |
# | 1   | Response Time        | Time taken to send a request and receive a response             | ms                 |
# | 2   | Availability         | Number of successful invocations/total invocations              | %                  |
# | 3   | Throughput           | Total Number of invocations for a given period of time          | invokes/second     |
# | 4   | Successability        | Number of response / number of request messages                | %                  |
# | 5   | Reliability          | Ratio of the number of error messages to total messages         | %                  |
# | 6   | Compliance           | The extent to which a WSDL document follows WSDL specification  | %                  |
# | 7   | Best Practices        | The extent to which a Web service follows WS-I Basic Profile    | %                  |
# | 8   | Latency              | Time taken for the server to process a given request            | ms                 |
# | 9   | Documentation        | Measure of documentation (i.e. description tags) in WSDL        | %                  |
# | 10  | WsRF                 | Web Service Relevancy Function: a rank for Web Service Quality  | %                  |
# | 11  | Service Classification | Levels representing service offering qualities (1 through 4)   | Classifier         |
# | 12  | Service Name         | Name of the Web service                                         | -                  |
# | 13  | WSDL Address         | Location of the Web Service Definition Language (WSDL) file on the Web | -              |

# %%
# Read first 5 rows
df.head()
# Out:
#    Response Time   Availability   Throughput   Successability   Reliability  \
# 0         302.75             89          7.1               90            73
# 1         482.00             85         16.0               95            73
# 2        3321.40             89          1.4               96            73
# 3         126.17             98         12.0              100            67
# 4         107.00             87          1.9               95            73
#
#     Compliance   Best Practices   Latency   Documentation       Service Name  \
# 0           78               80    187.75              32       MAPPMatching
# 1          100               84      1.00               2          Compound2
# 2           78               80      2.60              96           USDAData
# 3           78               82     22.77              89  GBNIRHolidayDates
# 4           89               62     58.33              93           CasUsers
#
#                                         WSDL Address Unnamed: 11
# 0  http://xml.assessment.com/service/MAPPMatching...         NaN
# 1  http://www.mssoapinterop.org/asmx/WSDL/compoun...         NaN
# 2  http://www.strikeiron.com/webservices/usdadata...         NaN
# 3  http://www.holidaywebservice.com/Holidays/GBNI...         NaN
# 4  http://galex.stsci.edu/casjobs/CasUsers.asmx?WSDL         NaN

# %%
# Read last 5 rows
df.tail()
# Out:
#       Response Time   Availability   Throughput   Successability  \
# 2498         200.80             93          2.4               98
# 2499          56.17             97         11.3               97
# 2500          93.93             80          2.1               80
# 2501         106.75             86          1.3               95
# 2502         316.50             72         15.9               72
#
#        Reliability   Compliance   Best Practices   Latency   Documentation  \
# 2498            73          100               84      7.40              41
# 2499            83           78               91      7.17               3
# 2500            67           78               82      3.72              60
# 2501            80           78               87      1.25              96
# 2502            80           89               87      5.50               8
#
#          Service Name                                       WSDL Address  \
# 2498   garnierService  http://genome.dkfz-heidelberg.de/menu/hobit/em...
# 2499         AWSAlexa   http://awis.amazonaws.com/AWSAlexa/AWSAlexa.wsdl
# 2500         interop2       http://www.cs.fsu.edu/~engelen/interop2.wsdl
# 2501  SailboatCalcsWS  http://pooh.poly.asu.edu/cst556-sailboatcalcsw...
# 2502  Slash/SOAP/Test                 http://use.perl.org/soap/Test.wsdl
#
#      Unnamed: 11
# 2498         NaN
# 2499         NaN
# 2500         NaN
# 2501         NaN
# 2502         NaN

# %%
# Information about the dataset
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2503 entries, 0 to 2502
# Data columns (total 12 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   Response Time    2503 non-null   float64
#  1    Availability    2503 non-null   int64
#  2    Throughput      2503 non-null   float64
#  3    Successability  2503 non-null   int64
#  4    Reliability     2503 non-null   int64
#  5    Compliance      2503 non-null   int64
#  6    Best Practices  2503 non-null   int64
#  7    Latency         2503 non-null   float64
#  8    Documentation   2503 non-null   int64
#  9    Service Name    2503 non-null   object
#  10   WSDL Address    2503 non-null   object
#  11  Unnamed: 11      2 non-null      object
# dtypes: float64(3), int64(6), object(3)
# memory usage: 234.8+ KB

# %%
# Information about the dataset
df.describe()
# Out:
#        Response Time   Availability   Throughput   Successability  \
# count    2503.000000    2503.000000  2503.000000      2503.000000
# mean      383.632129      81.141031     9.035757        83.881742
# std       564.548568      18.701398     7.734667        19.903213
# min        37.000000       7.000000     0.100000         8.000000
# 25%       142.335000      75.000000     2.800000        76.000000
# 50%       226.600000      87.000000     6.900000        95.000000
# 75%       348.215000      93.000000    13.300000        98.000000
# max      4989.670000     100.000000    43.100000       100.000000
#
#         Reliability   Compliance   Best Practices      Latency   Documentation
# count   2503.000000  2503.000000      2503.000000  2503.000000     2503.000000
# mean      69.777068    88.445865        79.296844    54.680995       31.279265
# std        8.576118    10.023243         7.816809   191.857554       31.485635
# min       33.000000    33.000000        50.000000     0.250000        1.000000
# 25%       67.000000    78.000000        75.000000     4.580000        6.000000
# 50%       73.000000    89.000000        82.000000    11.830000       11.000000
# 75%       73.000000   100.000000        84.000000    44.680000       42.000000
# max       89.000000   100.000000        95.000000  4140.350000       97.000000

# %%
# Find duplicate rows
print(df.duplicated().sum())
duplicates = df[df.duplicated(keep=False)]
print(duplicates)
# Out:
# 0
# Empty DataFrame
# Columns: [Response Time,  Availability,  Throughput,  Successability,  Reliability,  Compliance,  Best Practices,  Latency,  Documentation,  Service Name,  WSDL Address, Unnamed: 11]
# Index: []

# %%
# Calculate empty values for all columns
df.isnull().sum()
# Out:
# Response Time         0
#  Availability         0
#  Throughput           0
#  Successability       0
#  Reliability          0
#  Compliance           0
#  Best Practices       0
#  Latency              0
#  Documentation        0
#  Service Name         0
#  WSDL Address         0
# Unnamed: 11        2501
# dtype: int64

# %%
df["Unnamed: 11"].value_counts()
# Out:
# Unnamed: 11
# r=1.2/jax-wsa-sources/jaxwsa-ri/test/src/w3c/s11/etc/wsaTestService.wsdl    1
# r=1.3/jax-wsa-sources/jaxwsa-ri/test/src/w3c/s12/etc/wsaTestService.wsdl    1
# Name: count, dtype: int64

# %%
df[" Service Name"].value_counts()
# Out:
#  Service Name
# AnalysisWSAppLabImplService    102
# GoogleSearchService             43
# Service                         28
# AWSECommerceService             25
# Service1                        17
#                               ...
# ReportReadingWS                  1
# TaxonomyManager                  1
# RandomPlayer                     1
# User                             1
# Slash/SOAP/Test                  1
# Name: count, Length: 1639, dtype: int64

# %%
# Display the number of unique values in the "WSDL Address" column
df[" WSDL Address"].nunique()
# Out:
# 2379

# %% [markdown]
# # # Data Preprocess

# %%
df.drop("Unnamed: 11", axis=1, inplace=True)

# %%
df.columns
# Out:
# Index(['Response Time', ' Availability', ' Throughput', ' Successability',
#        ' Reliability', ' Compliance', ' Best Practices', ' Latency',
#        ' Documentation', ' Service Name', ' WSDL Address'],
#       dtype='object')

# %% [markdown]
# Rename columns beacause some columns have spaces(" ") in it's name. It'll make confusion will deploying in frontend. So we are going to Rename those columns

# %%
# Rename columns
df = df.rename(columns={
    ' Availability': 'Availability',
    ' Throughput': 'Throughput',
    ' Successability': 'Successability',
    ' Reliability': 'Reliability',
    ' Compliance': 'Compliance',
    ' Best Practices': 'Best Practices',
    ' Latency': 'Latency',
    ' Documentation': 'Documentation',
    ' Service Name': 'Service Name',
    ' WSDL Address': 'WSDL Address'
})

# %%
df.columns
# Out:
# Index(['Response Time', 'Availability', 'Throughput', 'Successability',
#        'Reliability', 'Compliance', 'Best Practices', 'Latency',
#        'Documentation', 'Service Name', 'WSDL Address'],
#       dtype='object')

# %%
# dataframe
df
# Out:
#       Response Time  Availability  Throughput  Successability  Reliability  \
# 0            302.75            89         7.1              90           73
# 1            482.00            85        16.0              95           73
# 2           3321.40            89         1.4              96           73
# 3            126.17            98        12.0             100           67
# 4            107.00            87         1.9              95           73
# ...             ...           ...         ...             ...          ...
# 2498         200.80            93         2.4              98           73
# 2499          56.17            97        11.3              97           83
# 2500          93.93            80         2.1              80           67
# 2501         106.75            86         1.3              95           80
# 2502         316.50            72        15.9              72           80
#
#       Compliance  Best Practices  Latency  Documentation       Service Name  \
# 0             78              80   187.75             32       MAPPMatching
# 1            100              84     1.00              2          Compound2
# 2             78              80     2.60             96           USDAData
# 3             78              82    22.77             89  GBNIRHolidayDates
# 4             89              62    58.33             93           CasUsers
# ...          ...             ...      ...            ...                ...
# 2498         100              84     7.40             41     garnierService
# 2499          78              91     7.17              3           AWSAlexa
# 2500          78              82     3.72             60           interop2
# 2501          78              87     1.25             96    SailboatCalcsWS
# 2502          89              87     5.50              8    Slash/SOAP/Test
#
#                                            WSDL Address
# 0     http://xml.assessment.com/service/MAPPMatching...
# 1     http://www.mssoapinterop.org/asmx/WSDL/compoun...
# 2     http://www.strikeiron.com/webservices/usdadata...
# 3     http://www.holidaywebservice.com/Holidays/GBNI...
# 4     http://galex.stsci.edu/casjobs/CasUsers.asmx?WSDL
# ...                                                 ...
# 2498  http://genome.dkfz-heidelberg.de/menu/hobit/em...
# 2499   http://awis.amazonaws.com/AWSAlexa/AWSAlexa.wsdl
# 2500       http://www.cs.fsu.edu/~engelen/interop2.wsdl
# 2501  http://pooh.poly.asu.edu/cst556-sailboatcalcsw...
# 2502                 http://use.perl.org/soap/Test.wsdl
#
# [2503 rows x 11 columns]

# %%
# Save the specified columns of the dataframe as a CSV file
df[['Response Time', 'Availability', 'Throughput', 'Successability', 'Reliability', 'Compliance', 'Best Practices', 'Latency', 'Documentation', 'WSDL Address']].to_csv("dataset/Final_data.csv")

# %% [markdown]
# ### Label encoding the object columns

# %%
# Store object column names
original_columns = df.select_dtypes(include='object').columns

# Initialize LabelEncoder
label_encoders = {}

# Apply LabelEncoder to each categorical variable
for col in original_columns:
    label_encoders[col] = LabelEncoder()
    df[col] = label_encoders[col].fit_transform(df[col])

# Print the mapping between original categories and numerical labels
for col, encoder in label_encoders.items():
    print(f"Mapping for column '{col}':")
    for label, category in enumerate(encoder.classes_):
        print(f"Label {label}: {category}")
    print("=====================")
# Out:
# Mapping for column 'Service Name':
# Label 0: AAIService
# Label 1: ABAService
# Label 2: ABRXMLPubSub
# Label 3: ABRXMLSearch
# Label 4: ACCLIPServiceService
# Label 5: ACMEProducts
# Label 6: ADQLTranslator
# Label 7: AIMSAddressWebService
# Label 8: AMIWebServiceService
# Label 9: AOSIFWSService
# Label 10: ARSA
# Label 11: ARTSPDF_Online_Collaboration
# Label 12: ASPFAQs
# Label 13: ASPNLexer
# Label 14: ASPNLogin
# Label 15: ASPNNewsFeeds
# Label 16: ATMService
# Label 17: ATTSMS
# Label 18: AWSAlexa
# Label 19: AWSECommerceService
# Label 20: AWSMechanicalTurkRequester
# Label 21: AccelerationUnit
# Label 22: AccountEventHandler
# Label 23: AccountInfo
# Label 24: AccountManagement
# Label 25: AccountService
# Label 26: AccountServiceNoHeader
# Label 27: AccountServices
# Label 28: AddressBookService
# Label 29: AddressFinder
# Label 30: AddressLookup
# Label 31: AddressManager
# Label 32: AddressVerifier
# Label 33: Admin
# Label 34: AdminService
# Label 35: Advanced
# Label 36: AffiliateService
# Label 37: Afstandsberegner
# Label 38: AircraftData
# Label 39: AirlineService
# Label 40: AirportDataService
# Label 41: AirportDelayService
# Label 42: AladinImageService
# Label 43: AllegroWebApiService
# Label 44: AmazonHistoricalPricing
# Label 45: AmazonSearchService
# Label 46: AmbitServiceService
# Label 47: Amortization
# Label 48: AnagramService
# Label 49: AnalysisWSAppLabImplService
# Label 50: AnalysisWSGowlabImplService
# Label 51: AnnotateService
# Label 52: Api
# Label 53: ApniUrdu
# Label 54: ApplicationPort
# Label 55: AppointmentServices
# Label 56: AreaService
# Label 57: AreaUnit
# Label 58: AreasAndVolumes
# Label 59: ArticleArchive
# Label 60: ArticleService
# Label 61: Articles
# Label 62: ArticlesSecure
# Label 63: AssociatedCheckerService
# Label 64: AtcoResDirect
# Label 65: AustralianPostCode
# Label 66: Authentication
# Label 67: AuthenticationService
# Label 68: AutoService
# Label 69: AvvioAPI
# Label 70: Award
# Label 71: B2BXMLOrders
# Label 72: BBWS
# Label 73: BCHService
# Label 74: BDEconomicosFinancieros
# Label 75: BEP
# Label 76: BFOGraphService
# Label 77: BGTBoundaryGeocoder
# Label 78: BINDService
# Label 79: BLiquidity
# Label 80: BNPrice
# Label 81: BNPriceWS
# Label 82: BNQuoteService
# Label 83: BSXMLAddressSearch
# Label 84: BagsOnNet
# Label 85: BankFinder
# Label 86: BankServiceService
# Label 87: BankValSOAP
# Label 88: BarCode
# Label 89: BarCodesService
# Label 90: BarbiWebServicesImplService
# Label 91: BaseformService
# Label 92: BasicAddressMatch
# Label 93: BasicRealTimeQuotes
# Label 94: Batch
# Label 95: Batch_Transfer
# Label 96: BcsoCorrections
# Label 97: Beheer
# Label 98: BetafaceWebService
# Label 99: BibShareSearchEngine
# Label 100: Bible
# Label 101: BillingSystemCall
# Label 102: BiologicalMarkupService
# Label 103: BirdwellMusicServices
# Label 104: Blast
# Label 105: BlastDemo
# Label 106: BlastbtService
# Label 107: BlogAPI
# Label 108: BlogBrowserService
# Label 109: BlogReaderService
# Label 110: BlogService
# Label 111: BlueLMSWS
# Label 112: BookInfoService
# Label 113: BtblastService
# Label 114: BuchungService
# Label 115: BulportFinanceService
# Label 116: BulportWeatherService
# Label 117: BusinessOrGovernmentalLookup
# Label 118: BusinessVerification
# Label 119: CBRFSearchSystem
# Label 120: CB_CD
# Label 121: CB_CH
# Label 122: CCChecker
# Label 123: CDASWS
# Label 124: CEqImage
# Label 125: CEqImageSecure
# Label 126: CH_CB
# Label 127: COTS
# Label 128: CPP_SCORE_REQUEST
# Label 129: CPP_SCORING_REQUEST
# Label 130: CPP_Status_Request
# Label 131: CRA_clima_GSRad
# Label 132: CRMService_v1
# Label 133: CRMTeeTimeAPI
# Label 134: CReasonerService
# Label 135: CSearch
# Label 136: CUCTransaction
# Label 137: CWS
# Label 138: CafePressServices
# Label 139: CalcAsyncService
# Label 140: CalcService
# Label 141: CalculationService
# Label 142: Calculator
# Label 143: CalculatorService
# Label 144: Calculator_x0020_Web_x0020_Service
# Label 145: Calculo
# Label 146: Calendar
# Label 147: CanadaAddressVerification
# Label 148: CaptchaService
# Label 149: CarCalculatorServiceService
# Label 150: CaribbeanT
# Label 151: CasGroups
# Label 152: CasJobs
# Label 153: CasService
# Label 154: CasUsers
# Label 155: CashFlowPresentValues
# Label 156: Catalog
# Label 157: CatalogService
# Label 158: Celsius42
# Label 159: CensusData
# Label 160: Cesar
# Label 161: ChartReq
# Label 162: ChebiWebServiceService
# Label 163: CheckAuthorizationService
# Label 164: CheckItOutClassService
# Label 165: Chemistry
# Label 166: CityLocations
# Label 167: ClientInformation
# Label 168: ClientService
# Label 169: Climate Data
# Label 170: ClusterfastaService
# Label 171: CodeGenService
# Label 172: CodeGenerator
# Label 173: Codic_x0020_Engine.Net_x0020_Web_x0020_Service
# Label 174: CodiceFiscale
# Label 175: CogoService
# Label 176: CommandService
# Label 177: CommuneInfoService
# Label 178: Communication
# Label 179: CompanyInfoService
# Label 180: Compound1
# Label 181: Compound2
# Label 182: ComputeDateTimeSpan
# Label 183: ConcertWebService
# Label 184: ConferenceService
# Label 185: ConfigEditingService
# Label 186: CongressionalDirectory
# Label 187: ConnectiqueService
# Label 188: ContactClean
# Label 189: ContactService
# Label 190: ContactServiceNoHeader
# Label 191: ContainerTrackingWebService
# Label 192: Content
# Label 193: ContentFinder
# Label 194: Context
# Label 195: Conversor
# Label 196: ConvertCSharp2VBService
# Label 197: CooccurrencesAllService
# Label 198: CooccurrencesService
# Label 199: CoolWSFromITM
# Label 200: CotizadorService
# Label 201: CounterDeleteInformationWS
# Label 202: CountryService
# Label 203: CountryServiceService
# Label 204: CourseRegistration
# Label 205: Courses
# Label 206: CreditCard
# Label 207: CreditCardValidator
# Label 208: Cryptarithm
# Label 209: CualEsMiIP
# Label 210: CupScores
# Label 211: CurrencyConvertor
# Label 212: CurrencyRates
# Label 213: CurrencyServerWebService
# Label 214: Current Homeland Security Threat Level
# Label 215: CurriculumOnlineProviderService
# Label 216: Curs
# Label 217: CursBCE
# Label 218: CustomFieldResponseWS
# Label 219: CustomerService
# Label 220: CustomersList
# Label 221: DDBJ
# Label 222: DEAWebsvcClass
# Label 223: DGV_SCADA
# Label 224: DMReporting
# Label 225: DNGatewatWebServiceService
# Label 226: DNS
# Label 227: DOTSAddressPlus
# Label 228: DOTSAddressValidate
# Label 229: DOTSContactValidation
# Label 230: DOTSCrypto
# Label 231: DOTSCurrencyExchange
# Label 232: DOTSEmailValidate
# Label 233: DOTSFastTax
# Label 234: DOTSFastWeather
# Label 235: DOTSFraudProtection
# Label 236: DOTSFraudProtectionLite
# Label 237: DOTSGeoCensus
# Label 238: DOTSGeoCoder
# Label 239: DOTSGeoPhone
# Label 240: DOTSGeoPinPoint
# Label 241: DOTSNameWizard
# Label 242: DOTSPackageTracking
# Label 243: DOTSPhoneAppend
# Label 244: DOTSTimeZoneAppend
# Label 245: DOTSValidateCanada
# Label 246: DOTSYellowPages
# Label 247: DPCWS
# Label 248: DailyDilbert
# Label 249: DailyHoro
# Label 250: DataEnhancement
# Label 251: DataGeneration
# Label 252: DataManager
# Label 253: DataService
# Label 254: DataSetService
# Label 255: DataTypes
# Label 256: DataUtil
# Label 257: DatabindingPatterns
# Label 258: DatasetBrowser
# Label 259: Date
# Label 260: DatosArt
# Label 261: DeadOrAlive
# Label 262: DealerLocator
# Label 263: DelayedStockQuote
# Label 264: Demo
# Label 265: DemographixQuery
# Label 266: DensityMap
# Label 267: Departements
# Label 268: DerniersDecesEPF
# Label 269: DetailZbozi
# Label 270: DevLeap_x0020_-_x0020_Codice_x0020_Fiscale
# Label 271: DevLeap_x0020_-_x0020_WSCached
# Label 272: DictService
# Label 273: DictionaryManager
# Label 274: DictmetaService
# Label 275: Dilbert
# Label 276: DimeInterop
# Label 277: DirSrvService
# Label 278: Directory
# Label 279: Discordian
# Label 280: DiscoveryService
# Label 281: DispatcherAPIService
# Label 282: Dispenser
# Label 283: DisponibilitaOutsourcerService
# Label 284: Distance
# Label 285: DistanceService
# Label 286: DistrictServiceService
# Label 287: DoNotCall
# Label 288: DocApi
# Label 289: DocumentManager
# Label 290: Domain
# Label 291: DotbotClass
# Label 292: DotnetDailyFact
# Label 293: DownloadService
# Label 294: DpsService
# Label 295: Drors
# Label 296: EAnalyzer
# Label 297: ECPAMT
# Label 298: EHCIntegrationService
# Label 299: EMBLNucleotideSequenceWebService
# Label 300: EMEP_SERVER
# Label 301: EMSFlightMonitorService
# Label 302: EPADWebServices
# Label 303: ERSWebCensusMapService
# Label 304: ESVService
# Label 305: ETP
# Label 306: EasyAmazonService
# Label 307: EbiService
# Label 308: EcMSoapBridgeService
# Label 309: EchoHeadersService
# Label 310: EchoService
# Label 311: EchoStringWSRoutingSvc
# Label 312: EconometricStats
# Label 313: EdgarInformation
# Label 314: EditService
# Label 315: EdmServiceService
# Label 316: ElectronicDataAssistance
# Label 317: ElementRefinementsService
# Label 318: EmailAddressValidator
# Label 319: EmailValidation
# Label 320: EmailVerNoTestEmail
# Label 321: EmailVerification
# Label 322: EmailVerify
# Label 323: EmptySA
# Label 324: EnGraphGPS
# Label 325: EncryptPointService
# Label 326: EnergyUnit
# Label 327: Ensembl
# Label 328: EnumFetchService
# Label 329: EnvioSMS
# Label 330: EquipmentData
# Label 331: ErrorReporter
# Label 332: Euro42
# Label 333: Events
# Label 334: ExPtLinkSampleService
# Label 335: ExampleService
# Label 336: ExceptionCollectionService
# Label 337: ExchangeRateService
# Label 338: ExchangeRates
# Label 339: Exchanges
# Label 340: ExecutablePackage
# Label 341: ExpandedCongoBuy_servoce
# Label 342: ExperimentWebService
# Label 343: ExternalCAP
# Label 344: FACISBackgroundCheck
# Label 345: FSCWarrantyClaimManagement_WebServices_TranslationToolService
# Label 346: FXWSService
# Label 347: FastCompletion
# Label 348: FastLanePlus
# Label 349: Fasta
# Label 350: Fax
# Label 351: FaxMessagingService
# Label 352: FaxService
# Label 353: FaxStatus
# Label 354: FileService
# Label 355: FileShopHandler
# Label 356: FileStoreService
# Label 357: FileTransferService
# Label 358: Files
# Label 359: FinanceService
# Label 360: FindBlankWS
# Label 361: FindIP
# Label 362: FindNearbyPOIService
# Label 363: FindService
# Label 364: FlickrComment
# Label 365: FlightHistoryService
# Label 366: FlightInformation
# Label 367: FlightRouteAggregatorService
# Label 368: FlightRouteService
# Label 369: FlightScheduleAggregatorService
# Label 370: FlightScheduleService
# Label 371: FloodService
# Label 372: FmWS
# Label 373: Footprinting
# Label 374: ForecastServiceImplService
# Label 375: ForumSecure
# Label 376: FpMLConversion
# Label 377: FpMLValidation
# Label 378: FraudLabsWebService
# Label 379: FrenchAddressVerification
# Label 380: FrequenciesService
# Label 381: FrequencyUnit
# Label 382: FsouOffice2003Service
# Label 383: FuelPricingServices
# Label 384: FullCongoBuy_servoce
# Label 385: FullerData_x0020_Fortune_x0020_Cookie
# Label 386: FullerData_x0020_High_x0020_Score_x0020_Service
# Label 387: Fungus
# Label 388: GBEAWHolidayDates
# Label 389: GBNIRHolidayDates
# Label 390: GBNIRHolidayService
# Label 391: GBSCTHolidayService
# Label 392: GD_VSDB_WMService
# Label 393: GFCore
# Label 394: GForgeAPI
# Label 395: GIS_CB
# Label 396: GLMService
# Label 397: GMPubSrvService
# Label 398: GSXWS
# Label 399: GWSRequest
# Label 400: Game
# Label 401: Gameshop
# Label 402: GatewayWSService
# Label 403: GeDat
# Label 404: GeneidmapService
# Label 405: GenerateMapService
# Label 406: GenericXsltCallback
# Label 407: GenreTermsAndSubjectHeadings
# Label 408: Geo2UTM
# Label 409: GeoAccess
# Label 410: GeoAddress
# Label 411: GeoBrokr
# Label 412: GeoCodeService
# Label 413: GeoCodeSrvService
# Label 414: GeoCode_Service
# Label 415: GeoIPService
# Label 416: GeoPointService
# Label 417: GeocodeService
# Label 418: GeocoderService
# Label 419: Geolizer
# Label 420: GetBestMapDefinitionService
# Label 421: GetCustomNews
# Label 422: GetEntertainmentListingsService
# Label 423: GetInfoByNameService
# Label 424: GetNodes
# Label 425: GetOrderInfo
# Label 426: GetOwamp
# Label 427: GetPeopleSearch
# Label 428: GetPersonInfoService
# Label 429: GetSomeValueService
# Label 430: GetSubjectElement
# Label 431: GetTradingConditions
# Label 432: GlenXMLService
# Label 433: Glide
# Label 434: GlimmermService
# Label 435: GlobalAddressInteractiveVerification
# Label 436: GlobalAddressVerification
# Label 437: GlobalWeather
# Label 438: GoogleSearchService
# Label 439: GoogleService
# Label 440: GraypotService
# Label 441: GreenchoiceNewCustomer
# Label 442: GroupsFinderService
# Label 443: Gtop
# Label 444: GtsInterfacesService
# Label 445: GuessWebService
# Label 446: GuidGenerator
# Label 447: GusbrcrzService
# Label 448: GuspmService
# Label 449: Guthrie
# Label 450: HAPWSClass
# Label 451: HBObauprodukte
# Label 452: HDSaldo
# Label 453: HOSTSupplierContainerRunService
# Label 454: HR-XML_x0020_Validation_x0020__x0028_2004-08_x0020_release_x0029_
# Label 455: HR-XML_x0020_Validation_x0020__x0028_2006-02_x0020_release_x0029_
# Label 456: HTTService
# Label 457: HWService
# Label 458: HashClass
# Label 459: HashProviderService
# Label 460: HawleyCreditCardValidate
# Label 461: HeaderTimeService
# Label 462: Headlines
# Label 463: HelloOpenSOAP
# Label 464: HelloService
# Label 465: HelloWorld
# Label 466: Helper
# Label 467: HexBinaryTest
# Label 468: Hill
# Label 469: HitCounter
# Label 470: HolaMundoWebS
# Label 471: HolidayService
# Label 472: HomeWorkService
# Label 473: HomeworkService
# Label 474: HoroscopeService
# Label 475: HostService
# Label 476: HotelFunctionsService
# Label 477: HotelsService
# Label 478: HouseofDev
# Label 479: Html2XmlServices
# Label 480: IAAUtilities
# Label 481: IACHSOAPservice
# Label 482: IAddress2service
# Label 483: IAddress3service
# Label 484: IAddressservice
# Label 485: IBTRNSOAPservice
# Label 486: ICD10
# Label 487: ICD9
# Label 488: ICD9Drug
# Label 489: ICD9ToICD10
# Label 490: IClientDataservice
# Label 491: IDEC_GeoServeis
# Label 492: IDV
# Label 493: IDutchservice
# Label 494: IHessServiceservice
# Label 495: IKtoPruefservice
# Label 496: ILohn2004service
# Label 497: IMSIVORY
# Label 498: IMucsService
# Label 499: IOHandler
# Label 500: IOremGeocoderservice
# Label 501: IP2CountryService
# Label 502: IP2Geo
# Label 503: IPHelpers
# Label 504: IPS
# Label 505: IPasswordservice
# Label 506: IRomanservice
# Label 507: ISMSServiceservice
# Label 508: ISOcode2shortformatSOAP
# Label 509: ISOcodesSOAP
# Label 510: ISecretaryXMLBrokerservice
# Label 511: IT_x0040_Service_x0020_Webservices
# Label 512: ITempConverterservice
# Label 513: ITicTacToeservice
# Label 514: ITranslateSvc
# Label 515: ITstSDNCHECKservice
# Label 516: IWSDLPublishservice
# Label 517: IWebAPIService
# Label 518: IXMLWS2service
# Label 519: IXMLWSservice
# Label 520: Icon
# Label 521: IdeasServiceService
# Label 522: IgetNumbersservice
# Label 523: ImageService
# Label 524: Image_x0020_Search
# Label 525: ImageryMetaDataService
# Label 526: ImgCount
# Label 527: ImgCutout
# Label 528: Import1
# Label 529: InTouchService
# Label 530: Inbound
# Label 531: InboxServiceNoHeader
# Label 532: IndianAddressVerification
# Label 533: IngesterServiceService
# Label 534: InsertRelation
# Label 535: InstantOrder
# Label 536: InsumaFocus
# Label 537: IntegrateServiceService
# Label 538: IntegrationService
# Label 539: InterFax
# Label 540: InterTranService
# Label 541: Interactive
# Label 542: Interop
# Label 543: InteropDef
# Label 544: InteropServiceAService
# Label 545: InteropServiceBService
# Label 546: InteropTestExtensibility
# Label 547: InteropTestExtensibilityRequired
# Label 548: InteropTestHeaders
# Label 549: Inventory
# Label 550: InvitationService
# Label 551: IsPublicationScientific
# Label 552: ItestckvSOAPservice
# Label 553: Izracun
# Label 554: JExamInfoServiceService
# Label 555: JIPComuniService
# Label 556: JIPNewsService
# Label 557: JSRMService
# Label 558: JanusAT
# Label 559: JanusSvc
# Label 560: JgluService
# Label 561: JobSequencerService
# Label 562: JobServices
# Label 563: JoeGustavServerService
# Label 564: JurisdictionLookupService
# Label 565: K4TAirFaresWS
# Label 566: K4TAirReservationsWS
# Label 567: K4TAirSellWS
# Label 568: K4THotelAvailWS
# Label 569: K4THotelSellWS
# Label 570: KBBEWebService
# Label 571: KBBilledWebservice
# Label 572: KEGG
# Label 573: KUAMNewsSyndicatedHeadlines
# Label 574: KeywordQueryService
# Label 575: KontoCheckService
# Label 576: KpiReport
# Label 577: L9C_BC
# Label 578: LDAPService
# Label 579: LM_GIS
# Label 580: LORAX
# Label 581: LOTTO_UK_NumberChecker
# Label 582: LVISWebService
# Label 583: Labs
# Label 584: LandmarkService
# Label 585: LanguageDictionary
# Label 586: LanguagesService
# Label 587: LeagueService
# Label 588: LeftCollocationFinderService
# Label 589: LeftNeighboursService
# Label 590: LetterSoup
# Label 591: Lists
# Label 592: LittServiceService
# Label 593: LitteratursidenServices
# Label 594: LocalSearchSrvService
# Label 595: LocalService
# Label 596: LocalTime
# Label 597: Localita
# Label 598: Location
# Label 599: LocationByZipService
# Label 600: Lodge
# Label 601: LogServices
# Label 602: LoggingService
# Label 603: LoginService
# Label 604: LookingForStrategyServices
# Label 605: LostvibeWebService
# Label 606: LottoDrawings
# Label 607: LowRPCService
# Label 608: MAGGIE
# Label 609: MAPPMatching
# Label 610: MAPPResults
# Label 611: MESAClaimsService
# Label 612: MFundsService
# Label 613: MNOAccessService
# Label 614: MSIT_MedStudentResidentValidation
# Label 615: MSInfoService
# Label 616: MSN
# Label 617: MacamMailer
# Label 618: MailService
# Label 619: MailServicePort
# Label 620: MailingList
# Label 621: Main
# Label 622: MainService
# Label 623: ManageLoginsAndRanges
# Label 624: ManageNumbers
# Label 625: MapImage
# Label 626: MapService
# Label 627: Mapping
# Label 628: MaranServiceService
# Label 629: MarketData
# Label 630: MarketSeg
# Label 631: MatchService
# Label 632: MathService
# Label 633: MathTools
# Label 634: Measurement
# Label 635: Medicare
# Label 636: MedicareData
# Label 637: MemberServices
# Label 638: MessageGroupService
# Label 639: MessageServerService
# Label 640: MessengerServiceAPI
# Label 641: MetadbSearchService
# Label 642: MetarService
# Label 643: MiriamProviderService
# Label 644: MlekoSluzba
# Label 645: MobileSoapServerService
# Label 646: MobileTextMessaging
# Label 647: MoneyCentralRemote
# Label 648: MonsterBusinessGatewayService
# Label 649: MorphingLabs
# Label 650: MorphologicalAnalysis_frontendService
# Label 651: MortgageIndex
# Label 652: MovieInformation
# Label 653: MultipleAlignment
# Label 654: MulttestService
# Label 655: MyAmazonPlus
# Label 656: MyAmazonSecure
# Label 657: MyWebService
# Label 658: MyWorld
# Label 659: NAF
# Label 660: NAICS
# Label 661: NBPRates
# Label 662: NED
# Label 663: NHB
# Label 664: NPOsMedicalPaginalTranslationService
# Label 665: NRA_x0020_ILA_x0020_News_x0020_Syndication
# Label 666: NRA_x0020_ILA_x0020_News_x0020_and_x0020_Updates_x0020_Syndication
# Label 667: NSVMCachingAPI
# Label 668: NSVMPublishingAPIV3
# Label 669: NWs
# Label 670: NamebankServiceService
# Label 671: NamespaceManager
# Label 672: NavFunctions
# Label 673: NavigatePublicationTarget
# Label 674: NavneNumreBasis
# Label 675: Nearest_x0020_Service
# Label 676: NetDicV08
# Label 677: NetToolsService
# Label 678: NetworkNode
# Label 679: News
# Label 680: NewsNArticles
# Label 681: NewsReaderService
# Label 682: NewsSearchService
# Label 683: NewsService
# Label 684: NewsServiceClient
# Label 685: NewsServices
# Label 686: NewsWebSvc
# Label 687: NominaliaWS
# Label 688: Northwind
# Label 689: Notas
# Label 690: NumPager
# Label 691: NumberGuess
# Label 692: NycAddressService
# Label 693: OA_CB
# Label 694: OA_DGV
# Label 695: ODWS
# Label 696: OD_CB
# Label 697: OECD.Stat_x0020_SDMX_x0020_web_x0020_service
# Label 698: OFACService
# Label 699: OHRwurmIndexService
# Label 700: OHRwurmSearchService
# Label 701: OMIM
# Label 702: OSSIWS
# Label 703: OTNDeptEmp
# Label 704: OTNGUIDGenerator
# Label 705: OTNHelloWorld
# Label 706: OTSZip
# Label 707: ObjectStateManager
# Label 708: OcrService
# Label 709: OddFactWebService
# Label 710: Office
# Label 711: OfficeResearch
# Label 712: Onegroupservice
# Label 713: OnlineMessenger
# Label 714: OpcXmlDaSrv
# Label 715: OrbitService
# Label 716: Order
# Label 717: OrderService
# Label 718: OutboundCallService
# Label 719: Overloaded
# Label 720: PCSDealers
# Label 721: PCtoLongLat
# Label 722: PDCWebService
# Label 723: PML
# Label 724: PO
# Label 725: POCP SOAP Interface
# Label 726: PTTInfo
# Label 727: PT_progetti
# Label 728: PaSSAPI
# Label 729: Palio_x0020_di_x0020_Siena
# Label 730: ParaciteSearchService
# Label 731: PartnerServices
# Label 732: PassportService
# Label 733: PasteHereWebService
# Label 734: PathFinderService
# Label 735: PathInfoBPService
# Label 736: PathwayService
# Label 737: PayPalAPIInterfaceService
# Label 738: PdsSoap
# Label 739: PeReverseAniService
# Label 740: PegsTourService
# Label 741: PeopleWS
# Label 742: PermitPlace
# Label 743: PersonService
# Label 744: PersonalizationService
# Label 745: Personalizer
# Label 746: Personne
# Label 747: PetWebServices
# Label 748: Phone
# Label 749: PhoneInteligence2
# Label 750: PhoneNotify
# Label 751: PhoneNumberEnhancement
# Label 752: PhoneService
# Label 753: PhoneValidator
# Label 754: PhoneVerify
# Label 755: Phonebook
# Label 756: Photoserver
# Label 757: PhylogeneticService
# Label 758: Pickup
# Label 759: PimlService
# Label 760: PingPong
# Label 761: PipelineManagerALE
# Label 762: PixelsToXYService
# Label 763: PlaceCatalogService
# Label 764: PlaceFinder
# Label 765: PlaceFinderSample
# Label 766: PluralsightWeather
# Label 767: PmSoapRpcApi
# Label 768: PoiManager
# Label 769: PolicyDocuments
# Label 770: PopulationWS
# Label 771: PostcodeService
# Label 772: Postcode_x0020_Finder
# Label 773: Presidential Election Results 2004
# Label 774: Primary
# Label 775: PrixElementPrestaServiceProxy
# Label 776: ProDA_WebServices
# Label 777: ProFoxWS
# Label 778: ProMLResolver
# Label 779: ProTagService
# Label 780: ProductActivation
# Label 781: ProductInfo
# Label 782: Products
# Label 783: ProfileSettingsService
# Label 784: PropertyInformation
# Label 785: Proverbs
# Label 786: Proximity
# Label 787: Public
# Label 788: PublicCalendar
# Label 789: PurchaseOrder
# Label 790: QSv2MsgProcessorService
# Label 791: QualificationWarranty
# Label 792: Query
# Label 793: QueryCheckService
# Label 794: QueryDeathIndex
# Label 795: QueryService
# Label 796: QueryServiceService
# Label 797: QueryWebserviceService
# Label 798: QuoteMachine
# Label 799: QuoteofTheDay
# Label 800: Quotes
# Label 801: QuranService
# Label 802: RCAWS
# Label 803: RGen
# Label 804: RNAhybridImplementationService
# Label 805: RNetService_v1
# Label 806: RPCSimapWSService
# Label 807: RSSService
# Label 808: RSSValidator
# Label 809: RSStoHTML
# Label 810: RadioMallWS
# Label 811: Random Quote
# Label 812: RandomBushismService
# Label 813: RandomDirectory
# Label 814: RandomGoogleSearchService
# Label 815: RandomPlayer
# Label 816: RandomService
# Label 817: Rankings
# Label 818: Rapportage
# Label 819: RateCalculatorService
# Label 820: RealTimeJobPost
# Label 821: RealTimeStockQuotes
# Label 822: RecommendationService
# Label 823: Reed_x0020_Affiliates_x0020_WebService
# Label 824: RefSeq
# Label 825: RegisterResearchServices
# Label 826: Registre
# Label 827: Remember_x0020_God
# Label 828: RemoteOnlineReadingWS
# Label 829: RenderServer3D
# Label 830: RenderService
# Label 831: Report
# Label 832: ReportReadingWS
# Label 833: ReportService
# Label 834: ReporteAereo
# Label 835: RepositoryInformation
# Label 836: Research
# Label 837: ResearchService
# Label 838: ResellerService
# Label 839: ResidentialLookup
# Label 840: Resources
# Label 841: RestrictedCheckTickets
# Label 842: RetHeaderService
# Label 843: RetrieveSingleRegistrationManager
# Label 844: RetsinfoService
# Label 845: ReverseGeocodingService
# Label 846: ReviewRequestManager
# Label 847: RightNeighboursService
# Label 848: Roll_x0020_Generator_x0020_Web_x0020_Service.
# Label 849: Round4XSDTest
# Label 850: RouteCalSrv2Service
# Label 851: RouteCalculationService
# Label 852: RouteFinder
# Label 853: RrnascanService
# Label 854: RsomService
# Label 855: Rss
# Label 856: Rss_Upload
# Label 857: RsvmService
# Label 858: SABLEArchiRPCService
# Label 859: SABLEModelServerRPCService
# Label 860: SABLEThermRPCService
# Label 861: SADownload
# Label 862: SBSWebService
# Label 863: SCADA_LM
# Label 864: SHUAAIndices
# Label 865: SIAP
# Label 866: SIMPS
# Label 867: SIMS
# Label 868: SMART
# Label 869: SMS
# Label 870: SMSGateway
# Label 871: SMSMessagingService
# Label 872: SMSTextMessaging
# Label 873: SMSWS
# Label 874: SMS_Service
# Label 875: SOAP
# Label 876: SOAPFaultService
# Label 877: SOAPReceive
# Label 878: SOAPSend
# Label 879: SOAPService
# Label 880: SOAP_AldiaService
# Label 881: SPRACI
# Label 882: SPS
# Label 883: SQLDataInterop
# Label 884: SQL_x0020_Formatter_x0020_Web_x0020_Service
# Label 885: SRS
# Label 886: SRWSampleService
# Label 887: SSOws
# Label 888: STK_SensorCollectionWebService
# Label 889: SWGCraftAPI
# Label 890: SZTAKI_Webster
# Label 891: SailboatCalcsWS
# Label 892: SaisieFrance2ServiceBeanService
# Label 893: SalesRankNPrice
# Label 894: SalesService
# Label 895: Sample
# Label 896: Sandbox6Service
# Label 897: SaraGridService
# Label 898: Schedule
# Label 899: ScheduleFileWebService
# Label 900: SchemaWeb
# Label 901: SdsUserAndHardwareService
# Label 902: SdssCutout
# Label 903: SdssFields
# Label 904: Search
# Label 905: SearchCuroCustomerService
# Label 906: SearchDnevnikSi
# Label 907: SearchEngine
# Label 908: SearchEngineWSService
# Label 909: SearchMusicTeachers
# Label 910: SearchNajdiSi
# Label 911: SearchService
# Label 912: SearchVecerCom
# Label 913: SecureLogin
# Label 914: Securlogin
# Label 915: SeikaCodePublish
# Label 916: SendContentService
# Label 917: SendContentServiceNoHeader
# Label 918: SendCustomForm
# Label 919: SendEmailService
# Label 920: SendPageService
# Label 921: SendSMSWorld
# Label 922: SendServiceNoHeader
# Label 923: SendSmsService
# Label 924: SendWM2Mail
# Label 925: SentencesService
# Label 926: SeqReferenceInfoEJB
# Label 927: SeqnaviSoapApiService
# Label 928: SerClsPeticionSOAPStratusMobipayservice
# Label 929: SerClsPeticionSOAPTPVPCservice
# Label 930: SerClsPeticionSOAPservice
# Label 931: SerClsRecolectaService
# Label 932: SerClsWSConsultaService
# Label 933: SerClsWSPasarelaPINPADService
# Label 934: ServerExampleService
# Label 935: ServerTime
# Label 936: Service
# Label 937: Service1
# Label 938: Service2
# Label 939: ServiceBilling
# Label 940: ServiceCategory
# Label 941: ServiceOverviewService
# Label 942: ServiceRequest
# Label 943: ServiceTransfert
# Label 944: ServicioGeocodificacion
# Label 945: ServicioNomenclator
# Label 946: ServicioOnix
# Label 947: ServicioRouting
# Label 948: ServicioSuma
# Label 949: ServicioVisualizacion
# Label 950: Servicio_C_de_Calidad
# Label 951: Servicio_Estadistica
# Label 952: Servicio_etiquetado
# Label 953: Servicio_ganaderos
# Label 954: Servicio_medio_ambiente
# Label 955: Servicio_saneamiento
# Label 956: SesameService
# Label 957: Session
# Label 958: SessionCreateRQService
# Label 959: SessionManagementServiceBinding
# Label 960: SessionService1
# Label 961: Settings
# Label 962: SforceService
# Label 963: SharewareService
# Label 964: Shipment
# Label 965: ShoppingCartTest
# Label 966: SignatureVerification
# Label 967: SimilarityService
# Label 968: Simple
# Label 969: SimpleTest
# Label 970: Sisu
# Label 971: SiteFetchService
# Label 972: SiteInspectService
# Label 973: SiteUser
# Label 974: SkyBoT
# Label 975: SkyNode
# Label 976: SkyNodeWS
# Label 977: Slash/SOAP/Test
# Label 978: SmartPayments
# Label 979: SmsApiService
# Label 980: SmsGate2
# Label 981: SmsGatewayService
# Label 982: SmsService
# Label 983: SmsTransfer
# Label 984: SnowReport
# Label 985: SoapGO
# Label 986: SoapResponder
# Label 987: SoapTest
# Label 988: SoapingService
# Label 989: SolarPlotsWebService
# Label 990: SortNumbers
# Label 991: Source_x0020_Code_x0020_Community_x0020_WebService
# Label 992: SpamCheckerService
# Label 993: SpatialQuery
# Label 994: SplitsTreeImplementationService
# Label 995: SportingGoodsFinder
# Label 996: StartService
# Label 997: StateCountryService
# Label 998: StateDemo
# Label 999: StateInfoSrv
# Label 1000: States_x0020__x0026__x0020_Provinces
# Label 1001: Statistics
# Label 1002: StockHistoryService
# Label 1003: StockQuote
# Label 1004: StockQuoteServiceService
# Label 1005: StockQuotes
# Label 1006: StockServices
# Label 1007: StreamContentService
# Label 1008: Streams
# Label 1009: StretcherService
# Label 1010: SubjectBrowserService
# Label 1011: SubscriptionManager
# Label 1012: SubscriptionService
# Label 1013: SudokuSolverWS
# Label 1014: SumibiConvertService
# Label 1015: SummaryService
# Label 1016: SurchargeRegisterService
# Label 1017: SushiwsPort
# Label 1018: SvnAdmin
# Label 1019: SwissCities
# Label 1020: SympaSOAP
# Label 1021: SyndicationServiceExperimental
# Label 1022: SynonymsService
# Label 1023: Systamex
# Label 1024: TCrossPlatformSoapService
# Label 1025: TGL_x0020_Web_x0020_Services_x0020_v1.0
# Label 1026: TMorse
# Label 1027: TNM_Elevation_Service
# Label 1028: TNM_Gazetteer_Service
# Label 1029: TNPubServicesXML
# Label 1030: TRMDemoBPService
# Label 1031: TRMStandardVersionService
# Label 1032: TVCaboEPG
# Label 1033: TWS-DR
# Label 1034: TWS-DS
# Label 1035: TWSFissionDotNet
# Label 1036: TWebService1
# Label 1037: TableJobs
# Label 1038: TargetServiceBinding
# Label 1039: TaricCZ
# Label 1040: Tax
# Label 1041: TaxData
# Label 1042: TaxDataComplete
# Label 1043: TaxonomyManager
# Label 1044: TelesignAPI
# Label 1045: Teletekst
# Label 1046: TempConvert
# Label 1047: TemperatureService
# Label 1048: TerraService
# Label 1049: Test Response Service
# Label 1050: TestService
# Label 1051: Testtool
# Label 1052: TexServices
# Label 1053: TextAnywhere_SMS
# Label 1054: TextGraphic
# Label 1055: TextToImage
# Label 1056: TfscanService
# Label 1057: ThaiSQL
# Label 1058: TheHolyBible
# Label 1059: The_x0020_Development_x0020_One_x0020_XMLTV_x0020_Web_x0020_Service
# Label 1060: The_x0020_Dolls_x0020_Gallery_x0020_Store_x0020__x0028_Web_x0020_Service_x0029_
# Label 1061: ThesaurusService
# Label 1062: TimeService
# Label 1063: TimeZones
# Label 1064: TipoCambio
# Label 1065: Tiscali_x0020_Messenger_x0020_Services
# Label 1066: Tiscali_x0020_Presence_x0020_Services
# Label 1067: Tiscali_x0020_Security_x0020_Services
# Label 1068: Tiscali_x0020_UMS_x0020_Accounting_x0020_Services
# Label 1069: Tools
# Label 1070: TorqueUnit
# Label 1071: TrWSEm
# Label 1072: TraceFinder3BPService
# Label 1073: TrafficService
# Label 1074: Translate
# Label 1075: TranslateSvc
# Label 1076: TransportService
# Label 1077: TravelCodesTranslator
# Label 1078: TwsLoan
# Label 1079: TwsPLNBUpdate
# Label 1080: Typograf
# Label 1081: UCDResolverService
# Label 1082: UDDIBusinessFinder
# Label 1083: UKAddressVerification
# Label 1084: UPCLookupService
# Label 1085: UPSRates
# Label 1086: USAddressVerification
# Label 1087: USDAData
# Label 1088: USGeocoding
# Label 1089: USHolidayDates
# Label 1090: USHolidayService
# Label 1091: USNG
# Label 1092: USWeather
# Label 1093: UniquesubsService
# Label 1094: UnitConversions
# Label 1095: UniversalThread
# Label 1096: UofA
# Label 1097: UpdatePerson
# Label 1098: UpdateService
# Label 1099: UpdatesService
# Label 1100: UpsValidation
# Label 1101: User
# Label 1102: UserAddModify
# Label 1103: UserManagement
# Label 1104: UserService
# Label 1105: Users
# Label 1106: Util
# Label 1107: Utility
# Label 1108: UtilityService
# Label 1109: VNetCenterInterfaceForSP
# Label 1110: VSOiService
# Label 1111: VTServiceProxy
# Label 1112: VaerkerService
# Label 1113: ValidateEmail
# Label 1114: ValidateSQL99Service
# Label 1115: ValidateService
# Label 1116: ValidationService
# Label 1117: Validator
# Label 1118: VasService
# Label 1119: VbidasService
# Label 1120: VersionService
# Label 1121: VideoGamesFinder
# Label 1122: ViewCountService
# Label 1123: Vigenere1
# Label 1124: VilibidVilibor
# Label 1125: VinService
# Label 1126: VipWebService
# Label 1127: VizieRBetaService
# Label 1128: VizieRService
# Label 1129: VocabularyTermsService
# Label 1130: WDDataService
# Label 1131: WHOIS
# Label 1132: WMLP
# Label 1133: WMLS
# Label 1134: WQS
# Label 1135: WS4lsqlService
# Label 1136: WSBlastpgpService
# Label 1137: WSCUVocal
# Label 1138: WSCitationImplService
# Label 1139: WSClustalWService
# Label 1140: WSCore
# Label 1141: WSDBFetchServerLegacyService
# Label 1142: WSDLInteropTestDocLit
# Label 1143: WSDLInteropTestDocLitParameters
# Label 1144: WSDLInteropTestDocLitService
# Label 1145: WSDLInteropTestListService
# Label 1146: WSDLInteropTestRpcEncService
# Label 1147: WSDaliLiteService
# Label 1148: WSEmbossService
# Label 1149: WSFastaService
# Label 1150: WSIndexService
# Label 1151: WSInterProScanService
# Label 1152: WSKalignService
# Label 1153: WSLoggildingar
# Label 1154: WSMPsrchService
# Label 1155: WSMafftService
# Label 1156: WSMaxsproutService
# Label 1157: WSMuscleService
# Label 1158: WSNCBIBlastService
# Label 1159: WSScanPSService
# Label 1160: WSTCoffeeService
# Label 1161: WSUser
# Label 1162: WSWUBlastService
# Label 1163: WahooScoresService
# Label 1164: WarrantyClaimWebService
# Label 1165: WaterService
# Label 1166: Weather
# Label 1167: WeatherStationService
# Label 1168: WebAcsWS
# Label 1169: WebBlogService
# Label 1170: WebBugService
# Label 1171: WebSearchWS
# Label 1172: WebService
# Label 1173: WebServiceAgentService
# Label 1174: WebServiceAuthenticator
# Label 1175: WebServiceDemo
# Label 1176: WebServices
# Label 1177: WebSitePulseService
# Label 1178: WebStoreAdminService
# Label 1179: WebStoreService
# Label 1180: WebSyndicationService
# Label 1181: WebSystemService
# Label 1182: Webservices.nl
# Label 1183: WemCarts
# Label 1184: WhiteMesaSoap12AddTestSvc
# Label 1185: WhiteYork_x0020_Hosting_x0020_Usage_x0020_Service
# Label 1186: WhoIsService
# Label 1187: WhoisService
# Label 1188: WikiWebService
# Label 1189: WitwService
# Label 1190: WolframSearchService
# Label 1191: Wordml2latexService
# Label 1192: WorldTimeService
# Label 1193: World_x0020_Time_x0020_Service
# Label 1194: WsdlContractFirstService
# Label 1195: Wsession
# Label 1196: X3WS
# Label 1197: XCShopService
# Label 1198: XEMBLService
# Label 1199: XFService
# Label 1200: XFormWebService
# Label 1201: XMLPortalService
# Label 1202: XMSServer
# Label 1203: XMethodsQuery
# Label 1204: XPIWS
# Label 1205: XWeb1003Port
# Label 1206: XWebBlog
# Label 1207: XWebCheckOut
# Label 1208: XWebEmailValidation
# Label 1209: XWebFAQs
# Label 1210: XWebLead
# Label 1211: XWebNews
# Label 1212: XWebSurvey
# Label 1213: XYToPixelsService
# Label 1214: XarayaSoap
# Label 1215: XataDispatchWebService
# Label 1216: XfccBasic
# Label 1217: XigniteArchive
# Label 1218: XigniteChart
# Label 1219: XigniteDataSet
# Label 1220: XigniteEdgar
# Label 1221: XigniteEmerging
# Label 1222: XigniteExchanges
# Label 1223: XigniteFunds
# Label 1224: XigniteGE
# Label 1225: XigniteHistorical
# Label 1226: XigniteHoldings
# Label 1227: XigniteInsider
# Label 1228: XigniteMaster
# Label 1229: XigniteMetals
# Label 1230: XigniteNews
# Label 1231: XigniteNote
# Label 1232: XigniteOFAC
# Label 1233: XigniteQuotes
# Label 1234: XigniteRates
# Label 1235: XigniteRealTime
# Label 1236: XigniteRegistration
# Label 1237: XigniteReleases
# Label 1238: XigniteSecurity
# Label 1239: XigniteSurvey
# Label 1240: XigniteTools
# Label 1241: XigniteVWAP
# Label 1242: XmlDailyFact
# Label 1243: XmlDemoService
# Label 1244: XmlHttpCheck
# Label 1245: XmlSelect
# Label 1246: XmlTracking
# Label 1247: XmppService
# Label 1248: YourHost
# Label 1249: ZELService
# Label 1250: ZacksConsensus
# Label 1251: ZacksSummary
# Label 1252: Zip
# Label 1253: Zip2Geo
# Label 1254: ZipCode
# Label 1255: ZipCodeLookup
# Label 1256: ZtpInterfacesService
# Label 1257: abiviewService
# Label 1258: acdcService
# Label 1259: acdtableService
# Label 1260: addUpdateUsers
# Label 1261: addressMeister.comService
# Label 1262: adid_apiService
# Label 1263: antigenicService
# Label 1264: aotm
# Label 1265: backtranambigService
# Label 1266: backtranseqService
# Label 1267: bananaService
# Label 1268: basicmap
# Label 1269: bibiwsImplementationService
# Label 1270: bidlistconnection_web_services
# Label 1271: biosedService
# Label 1272: bonjourwsdl
# Label 1273: btwistedService
# Label 1274: c2i_x0020_Service_x0020_Web_x0020_gratuit
# Label 1275: caiService
# Label 1276: captchaWebService
# Label 1277: categoryfeatures
# Label 1278: cathparseService
# Label 1279: ccydemo
# Label 1280: chaosService
# Label 1281: chargeService
# Label 1282: check
# Label 1283: checkVatService
# Label 1284: checkidService
# Label 1285: checktransService
# Label 1286: chipsService
# Label 1287: christmas
# Label 1288: cirdnaService
# Label 1289: ciselniky
# Label 1290: clover
# Label 1291: codcmpService
# Label 1292: codcopyService
# Label 1293: codeService
# Label 1294: codecoloring_service
# Label 1295: coderetService
# Label 1296: com.starwood.corona.apps.wdc.AirKiosk
# Label 1297: companyPaymentAuthorizationService
# Label 1298: compseqService
# Label 1299: consService
# Label 1300: cotsService
# Label 1301: countryip
# Label 1302: cpgplotService
# Label 1303: cpgreportService
# Label 1304: cuspService
# Label 1305: cutseqService
# Label 1306: cweather
# Label 1307: dConverterSOAP
# Label 1308: danService
# Label 1309: dbEMSW2
# Label 1310: decompImplementationService
# Label 1311: default_test
# Label 1312: degapseqService
# Label 1313: demoService
# Label 1314: descseqService
# Label 1315: devCadastro
# Label 1316: dic2
# Label 1317: diffseqService
# Label 1318: digestService
# Label 1319: distmatService
# Label 1320: domainresoService
# Label 1321: domainsweepService
# Label 1322: dotmatcherService
# Label 1323: dotpathService
# Label 1324: dottupService
# Label 1325: dregService
# Label 1326: e2gImplementationService
# Label 1327: eBayAPIInterfaceService
# Label 1328: eBayWatcherService
# Label 1329: eBob42CSharp
# Label 1330: eFetchService
# Label 1331: ePrecis
# Label 1332: eSynapsFeed
# Label 1333: eSynapsMonitor
# Label 1334: eSynapsSerach
# Label 1335: eUtilsService
# Label 1336: eZentrum-Webservices
# Label 1337: echoService
# Label 1338: edit__descseqService
# Label 1339: ehmmcalibrateService
# Label 1340: ehmmemitService
# Label 1341: ehmmfetchService
# Label 1342: ehmmindexService
# Label 1343: ehmmpfamService
# Label 1344: einvertedService
# Label 1345: elewebdir
# Label 1346: emastService
# Label 1347: embossdataService
# Label 1348: embossversionService
# Label 1349: ememeService
# Label 1350: emmaService
# Label 1351: emowseService
# Label 1352: engtoarabic
# Label 1353: entretService
# Label 1354: epestfindService
# Label 1355: eprimer3Service
# Label 1356: equicktandemService
# Label 1357: erez2
# Label 1358: erez3
# Label 1359: est2genomeService
# Label 1360: etandemService
# Label 1361: etrayService
# Label 1362: excuses
# Label 1363: executor
# Label 1364: extractfeatService
# Label 1365: extractseqService
# Label 1366: eyeVeri
# Label 1367: fandgSubscriptionWS
# Label 1368: fconsenseService
# Label 1369: fdiscbootService
# Label 1370: fdnacompService
# Label 1371: fdnadistService
# Label 1372: fdnainvarService
# Label 1373: fdollopService
# Label 1374: fdolpennyService
# Label 1375: fdrawtreeService
# Label 1376: featureDetails
# Label 1377: findkmService
# Label 1378: finnwordsService
# Label 1379: flights
# Label 1380: forward
# Label 1381: fpennyService
# Label 1382: fpromlkService
# Label 1383: freakService
# Label 1384: frestdistService
# Label 1385: fseqbootService
# Label 1386: ftreedistService
# Label 1387: ftreedistpairService
# Label 1388: fuzznucService
# Label 1389: fuzzproService
# Label 1390: fuzztranService
# Label 1391: garnierService
# Label 1392: gcat
# Label 1393: geeceeService
# Label 1394: generate_login_token
# Label 1395: geographyRequests
# Label 1396: geoservices
# Label 1397: getGeoInfo
# Label 1398: getJoke
# Label 1399: getMapwsdl
# Label 1400: getOtherInformation
# Label 1401: getfile2
# Label 1402: getgeoobjects
# Label 1403: getorfService
# Label 1404: gmews
# Label 1405: grtnwsSOAP
# Label 1406: guidissue
# Label 1407: helixturnhelixService
# Label 1408: hellowsdl
# Label 1409: hellowsdl2
# Label 1410: hellowsdl3
# Label 1411: hetparseService
# Label 1412: hmomentService
# Label 1413: hts
# Label 1414: iMobilWS
# Label 1415: iepService
# Label 1416: imageConvert
# Label 1417: infoalignService
# Label 1418: infoseqService
# Label 1419: interop
# Label 1420: interop2
# Label 1421: interop2B
# Label 1422: interop2C
# Label 1423: interopDocSvc
# Label 1424: interopLab
# Label 1425: interopLabEchoHeader
# Label 1426: interpublish
# Label 1427: ippcService
# Label 1428: isochoreService
# Label 1429: jobsService
# Label 1430: kSMSSoap
# Label 1431: kalendar
# Label 1432: learn
# Label 1433: lindnaService
# Label 1434: lister
# Label 1435: listorService
# Label 1436: lmapi
# Label 1437: locationRouting
# Label 1438: logon
# Label 1439: lu
# Label 1440: magic
# Label 1441: marketService
# Label 1442: marscanService
# Label 1443: maskfeatService
# Label 1444: maskseqService
# Label 1445: matcherService
# Label 1446: mdWebServices
# Label 1447: megamergerService
# Label 1448: merchant-interface-mime
# Label 1449: mergerService
# Label 1450: msbarService
# Label 1451: msd_soap_service
# Label 1452: muller
# Label 1453: mwcontamService
# Label 1454: mwfilterService
# Label 1455: myService
# Label 1456: nEkaWebService
# Label 1457: nalennd
# Label 1458: ndfdXML
# Label 1459: needleService
# Label 1460: net.xmethods.services.stockquote.StockQuoteService
# Label 1461: newcpgreportService
# Label 1462: newcpgseekService
# Label 1463: news
# Label 1464: news_xml_service
# Label 1465: newseqService
# Label 1466: noreturnService
# Label 1467: notification
# Label 1468: notseqService
# Label 1469: nthseqService
# Label 1470: nucleic_cpg_islands__newcpgseekService
# Label 1471: octanolService
# Label 1472: oddcompService
# Label 1473: oemsearchxmle
# Label 1474: otoMotoWebApi
# Label 1475: paddleService
# Label 1476: palindromeService
# Label 1477: pasteseqService
# Label 1478: pathwayDBSer
# Label 1479: patmatdbService
# Label 1480: patmatmotifsService
# Label 1481: pbx
# Label 1482: pdbtospService
# Label 1483: pepcoilService
# Label 1484: pepinfoService
# Label 1485: pepnetService
# Label 1486: pepstatsService
# Label 1487: pepwheelService
# Label 1488: pepwindowService
# Label 1489: pepwindowallService
# Label 1490: periodictable
# Label 1491: pinger
# Label 1492: plotconService
# Label 1493: plotorfService
# Label 1494: politicalareareport
# Label 1495: polydotService
# Label 1496: pregService
# Label 1497: premiumuser package
# Label 1498: prettyplotService
# Label 1499: prettyseqService
# Label 1500: primersearchService
# Label 1501: processParticipant
# Label 1502: productPortalWS
# Label 1503: profitService
# Label 1504: promotionService
# Label 1505: prophecyService
# Label 1506: prophetService
# Label 1507: protein_2d_structure__hmomentService
# Label 1508: protseq
# Label 1509: protsweepService
# Label 1510: pscanService
# Label 1511: psiphiService
# Label 1512: racer
# Label 1513: rbac_serverService
# Label 1514: reasoner
# Label 1515: recoderService
# Label 1516: redataService
# Label 1517: registeronline
# Label 1518: registration
# Label 1519: remapService
# Label 1520: remoteQuery
# Label 1521: replicaCatalogService
# Label 1522: restoverService
# Label 1523: restrictService
# Label 1524: retsinfoService
# Label 1525: revseqService
# Label 1526: roconService
# Label 1527: rshare
# Label 1528: rt_info
# Label 1529: s_news
# Label 1530: sample
# Label 1531: sandriniWebService
# Label 1532: sbml
# Label 1533: sbp
# Label 1534: scavenger_hunt
# Label 1535: sdm25
# Label 1536: search
# Label 1537: searchService
# Label 1538: seealsoService
# Label 1539: sekeywordService
# Label 1540: sendOIOXML
# Label 1541: seqmatchallService
# Label 1542: seqretService
# Label 1543: seqretsplitService
# Label 1544: serviceName
# Label 1545: service_test
# Label 1546: sfconnector
# Label 1547: showalignService
# Label 1548: showdbService
# Label 1549: showfeatService
# Label 1550: showmyip
# Label 1551: showmyip_lookup
# Label 1552: showorfService
# Label 1553: showseqService
# Label 1554: shuffleseqService
# Label 1555: sigcleaveService
# Label 1556: siggenService
# Label 1557: sigscanService
# Label 1558: silentService
# Label 1559: sirnaService
# Label 1560: sixpackService
# Label 1561: skipseqService
# Label 1562: sms
# Label 1563: soap4buildwsdl
# Label 1564: splitterService
# Label 1565: stock
# Label 1566: stretcherService
# Label 1567: stssearchService
# Label 1568: sugarsoap
# Label 1569: supermatcherService
# Label 1570: svcAMBatchService
# Label 1571: sycoService
# Label 1572: symgateEngine
# Label 1573: tbapi
# Label 1574: tcodeService
# Label 1575: testService
# Label 1576: textsearchService
# Label 1577: tfmService
# Label 1578: tfscanService
# Label 1579: timeDateEmail
# Label 1580: timetabling
# Label 1581: tipService
# Label 1582: tipsService
# Label 1583: tmapService
# Label 1584: toi-wetter
# Label 1585: tranalignService
# Label 1586: transeqService
# Label 1587: trimestService
# Label 1588: trimseqService
# Label 1589: twodsweepService
# Label 1590: twofeatService
# Label 1591: uBioService
# Label 1592: unionService
# Label 1593: updater
# Label 1594: utils_database_indexing__dbigcgService
# Label 1595: v40
# Label 1596: valdoc
# Label 1597: validateAddress_Service
# Label 1598: vectorstripService
# Label 1599: vrnaalifoldpfService
# Label 1600: vrnacofoldService
# Label 1601: vrnacofoldpfService
# Label 1602: vrnadistanceService
# Label 1603: vrnaduplexService
# Label 1604: vrnaevalService
# Label 1605: vrnaheatService
# Label 1606: vrnainverseService
# Label 1607: vrnaplotService
# Label 1608: vrnasuboptService
# Label 1609: w_company
# Label 1610: w_invoicereceipt
# Label 1611: walker_service
# Label 1612: waterService
# Label 1613: wbs_publicservicesService
# Label 1614: weasel
# Label 1615: webservice
# Label 1616: whatizit
# Label 1617: whichdbService
# Label 1618: wobbleService
# Label 1619: wordcountService
# Label 1620: wordmatchService
# Label 1621: wossnameService
# Label 1622: ws
# Label 1623: wsArrayList
# Label 1624: wsDataSet
# Label 1625: wsDice
# Label 1626: wsDomainDoctor
# Label 1627: wsRegistriCertificati
# Label 1628: wsReqSender
# Label 1629: wsStrings
# Label 1630: wsTravelService
# Label 1631: wsaTestService
# Label 1632: wsdl
# Label 1633: xfrx
# Label 1634: yankService
# Label 1635: zCalcSvc
# Label 1636: zbozi
# Label 1637: zipCodeClass
# Label 1638: zipinfo
# =====================
# Mapping for column 'WSDL Address':
# Label 0: http://01792.org/webservices/PCtoLongLat.asmx?wsdl
# Label 1: http://140.115.51.161:8080/bpelengine/services/PathInfoBP?wsdl
# Label 2: http://140.115.51.161:8080/bpelengine/services/TRMDemoBP?WSDL
# Label 3: http://140.115.51.161:8080/bpelengine/services/TRMStandardVersion?wsdl
# Label 4: http://140.115.51.161:8080/bpelengine/services/TraceFinder3BP?wsdl
# Label 5: http://140.129.79.217/WS/WSProvider_SecretaryXMLFormBroker.exe/wsdl/ISecretaryXMLBroker
# Label 6: http://195.68.94.163:8001/WS_SecurLogin.asmx?WSDL
# Label 7: http://198.228.90.222:8080/ideas/services/IdeasService?wsdl
# Label 8: http://202.75.163.45:2503/ECPAWSDL/ECPAMT.WSDL
# Label 9: http://212.166.209.24:80/ConnectorGateway/services/GatewayWS?wsdl
# Label 10: http://212.177.98.35/swapping/default.asmx?WSDL
# Label 11: http://212.177.98.35/swapping/default.test.asmx?WSDL
# Label 12: http://62.23.140.25/plg/services/ConnectiqueService.asmx?WSDL
# Label 13: http://62.61.91.207/webservices/Sisu?WSDL
# Label 14: http://66.153.51.16/MSIT/PDR.Net/MSIT_PDR_SERVICES/MSIT_MedStudentResidentValidation.asmx?wsdl
# Label 15: http://85.10.210.46:8989/joegustav/services/JoeGustavServer?wsdl
# Label 16: http://aber.com.mk/ws.php?wsdl
# Label 17: http://addressmeister.bizware.com/service/wsdl/server.soap.2.wsdl
# Label 18: http://addressmeister.bizware.com/service/wsdl/server.soap.wsdl
# Label 19: http://adid.vexcom.com/adid_api.cfc?wsdl
# Label 20: http://admin.brandedsms.com/TexServices.asmx?wsdl
# Label 21: http://advcentral.adventresources.com/bmwistar/forward.php?wsdl
# Label 22: http://agents.startcorp.com/As/XmppService.asmx?wsdl
# Label 23: http://ahp.amazonaws.com/AmazonHistoricalPricing/2005-10-19/AmazonHistoricalPricing.wsdl
# Label 24: http://amadeus.biosci.arizona.edu/~nirav/batch2.wsdl
# Label 25: http://amadeus.biosci.arizona.edu/~nirav/learn.wsdl
# Label 26: http://angelika-fochler.gmxhome.de/PHP-Google/GoogleSearch.wsdl
# Label 27: http://anonymous:anonymous@wortschatz.uni-leipzig.de/axis/services/RightNeighbours?wsdl
# Label 28: http://ao.sa.dk/LAView/ImageServer/Service1.asmx?WSDL
# Label 29: http://api.cafepress.com/index.asmx?wsdl
# Label 30: http://api.legiomedia.com/Content.asmx?WSDL
# Label 31: http://api.legiomedia.com/Users.asmx?WSDL
# Label 32: http://api.playstream.com/3.0/StreamContentService.asmx?wsdl
# Label 33: http://api.transvector2.it/products.asmx?Wsdl
# Label 34: http://api.transvector2.it/swapping/default.asmx?wsdl
# Label 35: http://api.veritate.net/axis/services/EdmService?wsdl
# Label 36: http://arccf10.tor.ec.gc.ca/climate/functions/climatedata.cfc?wsdl
# Label 37: http://arcweb.esri.com/services/v1/MapImage.wsdl
# Label 38: http://arcweb.esri.com/services/v1/Query.wsdl
# Label 39: http://arcweb.esri.com/services/v2/AccountInfo.wsdl
# Label 40: http://arcweb.esri.com/services/v2/AddressFinder.wsdl
# Label 41: http://arcweb.esri.com/services/v2/AddressManager.wsdl
# Label 42: http://arcweb.esri.com/services/v2/Authentication.wsdl
# Label 43: http://arcweb.esri.com/services/v2/MapImage.wsdl
# Label 44: http://arcweb.esri.com/services/v2/PlaceFinder.wsdl
# Label 45: http://arcweb.esri.com/services/v2/PlaceFinderSample.wsdl
# Label 46: http://arcweb.esri.com/services/v2/PoiManager.wsdl
# Label 47: http://arcweb.esri.com/services/v2/Proximity.wsdl
# Label 48: http://arcweb.esri.com/services/v2/Query.wsdl
# Label 49: http://arcweb.esri.com/services/v2/Report.wsdl
# Label 50: http://arcweb.esri.com/services/v2/RouteFinder.wsdl
# Label 51: http://arcweb.esri.com/services/v2/Utility.wsdl
# Label 52: http://arcweb.esri.com/services/v2006/PlaceFinderSample.wsdl
# Label 53: http://arcwebstg.esri.com/services/v2006/ContentFinder.wsdl
# Label 54: http://arcwebstg.esri.com/services/v2006/MapImage.wsdl
# Label 55: http://arcwebstg.esri.com/services/v2006/Report.wsdl
# Label 56: http://arestestsite.communityzero.com/ws/api/Session.wsdl
# Label 57: http://ariadne.cs.kuleuven.ac.be/AWS/services/TargetService?wsdl
# Label 58: http://aspalliance.com/dotnetsolutions/WebService4/Service1.asmx?wsdl
# Label 59: http://aspalliance.com/nothingmn/guid.asmx?wsdl
# ...
# Label 2136: http://www.terraserver.microsoft.com/LandmarkService.asmx?WSDL
# Label 2137: http://www.terraservice.net/LandmarkService.asmx?WSDL
# Label 2138: http://www.terraservice.net/TerraService2.asmx?wsdl
# Label 2139: http://www.terraservice.net/terraservice.asmx?wsdl
# Label 2140: http://www.textdisguise.com/TextDisguise/ClientService/ClientService.asmx?wsdl
# Label 2141: http://www.thaisql.com/ws/dotnet/webservices.asmx?wsdl
# Label 2142: http://www.thecave.com/ws/snowreport.wsdl
# Label 2143: http://www.thomasbouche.com/WS/Transfert/WSTransfert.asmx?wsdl
# Label 2144: http://www.ticketnetworkdirect.com/webservices/TNPubServicesXML.asmx?wsdl
# Label 2145: http://www.tilisoft.com/ws/eyeVeri/eyeVeri.asmx?wsdl
# Label 2146: http://www.timhibbard.com/webservices/engraphgps/engraph.asmx?wsdl
# Label 2147: http://www.titleinfo.com/DocumentWebService/PolicyDocuments.asmx?wsdl
# Label 2148: http://www.toolxite.dk/wsdl/orbit_service.1.0.wsdl
# Label 2149: http://www.toolxite.dk/wsdl/orbit_service.wsdl
# Label 2150: http://www.tpisoft.com/smartpayments/transact.asmx?WSDL
# Label 2151: http://www.tpisoft.com/smartpayments/validate.asmx?WSDL
# Label 2152: http://www.translated.net/hts/soap.php?wsdl
# Label 2153: http://www.travelmatic.biz/webservices/flightAvailWs.php?wsdl
# Label 2154: http://www.travelnow.com/services/HotelServices200520?WSDL
# Label 2155: http://www.travelwithjan.com/thaisky/rsu/cit695/homework.asmx?wsdl
# Label 2156: http://www.trustedwebservices.org/trustedx/downloads/DigitalSignature.wsdl
# Label 2157: http://www.trustedwebservices.org/trustedx/downloads/SignatureVerify.wsdl
# Label 2158: http://www.tunguyen.us/wslearn/northwind.asmx?wsdl
# Label 2159: http://www.tv-grossbottwar.de/WebServices/Game.asmx?WSDL
# Label 2160: http://www.ulabs.science.ubc.ca/pub/interface/ws_server.php?wsdl
# Label 2161: http://www.unifiedsoftware.co.uk/BankVal.wsdl
# Label 2162: http://www.unifiedsoftware.co.uk/BankValgetdetail.wsdl
# Label 2163: http://www.universalthread.com/WebService/UniversalThread.asmx?wsdl
# Label 2164: http://www.unpicked.com/webservices/whois/whois.asmx?wsdl
# Label 2165: http://www.upcplus.com/BackEnd/User/User.asmx?wsdl
# Label 2166: http://www.update.uu.se/~adde/mt/lib/MT/GoogleSearch.wsdl
# Label 2167: http://www.usatlas.bnl.gov/~dladams/dial/releases/0.94/dial/dial_ws_ami/gsoap/dial_ws_ami.wsdl
# Label 2168: http://www.usatlas.bnl.gov/~dladams/dial/releases/1.00/dial/dial_ws_ami/gsoap/dial_ws_ami.wsdl
# Label 2169: http://www.usatlas.bnl.gov/~dladams/dial/releases/1.10/dial/dial_ws_ami/gsoap/dial_ws_ami.wsdl
# Label 2170: http://www.usatlas.bnl.gov/~dladams/dial/releases/1.20/dial/dial_ws_ami/gsoap/dial_ws_ami.wsdl
# Label 2171: http://www.usfnet.com/WebServices/HostService?WSDL
# Label 2172: http://www.v-tis.net/VtisFluid/Measurement.asmx?wsdl
# Label 2173: http://www.valil.com/ChessWebService/Service.asmx?wsdl
# Label 2174: http://www.vapoultrygrowers.com/VPGC-Web/Global/SecureLogin.asmx?WSDL
# Label 2175: http://www.vareliefsale.com/VRS-Web/Global/SecureLogin.asmx?WSDL
# Label 2176: http://www.vbi.vt.edu/~pathport/services/wsdls/clusterblast.wsdl
# Label 2177: http://www.vbi.vt.edu/~pathport/services/wsdls/clusterfasta.wsdl
# Label 2178: http://www.vbi.vt.edu/~pathport/services/wsdls/geneidmap.wsdl
# Label 2179: http://www.vbi.vt.edu/~pathport/services/wsdls/glimmerm.wsdl
# Label 2180: http://www.vbi.vt.edu/~pathport/services/wsdls/multtest.wsdl
# Label 2181: http://www.vbi.vt.edu/~pathport/services/wsdls/pathinfo.wsdl
# Label 2182: http://www.vbi.vt.edu/~pathport/services/wsdls/rrnascan.wsdl
# Label 2183: http://www.vbi.vt.edu/~pathport/services/wsdls/rsom.wsdl
# Label 2184: http://www.vbi.vt.edu/~pathport/services/wsdls/stretcher.wsdl
# Label 2185: http://www.vbi.vt.edu/~pathport/services/wsdls/tfscan.wsdl
# Label 2186: http://www.vbi.vt.edu/~pathport/services/wsdls/uniquesubs.wsdl
# Label 2187: http://www.vbi.vt.edu/~pathport/services/wsdls/vbidas.wsdl
# Label 2188: http://www.vbi.vt.edu/~pathport/services/wsdls/water.wsdl
# Label 2189: http://www.vbnetexpert.com/vsm/timeservice/servertime.asmx?wsdl
# Label 2190: http://www.vbtrain.net/samplewebprojects/Web%20Interaction%20Sample/timeDateEmail.asmx?wsdl
# Label 2191: http://www.velocedge.com/Net/LMWAPI/service1.asmx?wsdl
# Label 2192: http://www.verticaltruth.com/VTServiceProxy.asmx?WSDL
# Label 2193: http://www.vfri.org/VFRI-Web/Global/SecureLogin.asmx?WSDL
# Label 2194: http://www.viamichelin.com/ws/services/FindNearbyPOI?wsdl
# Label 2195: http://www.viamichelin.com/ws/services/GenerateMap?wsdl
# Label 2196: http://www.viamichelin.com/ws/services/GetBestMapDefinition?wsdl
# Label 2197: http://www.viamichelin.com/ws/services/PixelsToXY?wsdl
# Label 2198: http://www.viamichelin.com/ws/services/ReverseGeocoding?wsdl
# Label 2199: http://www.viamichelin.com/ws/services/RouteCalculation?wsdl
# Label 2200: http://www.viamichelin.com/ws/services/XYToPixels?wsdl
# Label 2201: http://www.vinfo.com/Updates/TGPlugIn/ProductInfo.asmx?wsdl
# Label 2202: http://www.viphousesearch.com/Apps/WebService/SendCustomForm.asmx?WSDL
# Label 2203: http://www.vit.org/WebServices/ContainerTrackingWebService.asmx?WSDL
# Label 2204: http://www.vmrc.org/VMRCPortal/Global/SecureLogin.asmx?WSDL
# Label 2205: http://www.w3.org/2002/ws/databinding/edcopy/testsuite/documents/all/all.wsdl
# Label 2206: http://www.w3.org/2002/ws/databinding/edcopy/testsuite/documents/names/names.wsdl
# Label 2207: http://www.w3coder.com/ws/email/FindIP.asmx?wsdl
# Label 2208: http://www.w3schools.com/webservices/tempconvert.asmx?WSDL
# Label 2209: http://www.walkermowers.com/ws/opei/WarrantyClaimService2.wsdl
# Label 2210: http://www.walkermowers.com/ws/opei/WarrantyClaimService4.wsdl
# Label 2211: http://www.walkermowers.com/ws/opei/claimb.wsdl
# Label 2212: http://www.walkermowers.com/ws/opei/claimc.wsdl
# Label 2213: http://www.walkermowers.com/ws/opei/claime.wsdl
# Label 2214: http://www.walkermowers.com/ws/services.wsdl
# Label 2215: http://www.wce.ca/ReportService.asmx?wsdl
# Label 2216: http://www.weather.gov/forecasts/xml/DWMLgen/wsdl/ndfdXML.wsdl)
# Label 2217: http://www.weather.gov/forecasts/xml/SOAP_server/ndfdXMLserver.php?wsdl
# Label 2218: http://www.web-mojo.com/ssnvalidate.asmx?wsdl
# Label 2219: http://www.webcontinuum.net/webservices/ccydemo.asmx?wsdl
# Label 2220: http://www.webcontinuum.net/webservices/ccydemo.wsdl
# Label 2221: http://www.webservices.scot.nhs.uk/JobWebServices/service.asmx?WSDL
# Label 2222: http://www.webservicex.com/AustralianPostCode.asmx?WSDL
# Label 2223: http://www.webservicex.com/EMBLNucleotideSequenceWebService.asmx?wsdl
# Label 2224: http://www.webservicex.com/FinanceService.asmx?WSDL
# Label 2225: http://www.webservicex.com/NAICS.asmx?wsdl
# Label 2226: http://www.webservicex.com/UDDIBusinessFinder.asmx?WSDL
# Label 2227: http://www.webservicex.com/barcode.asmx?WSDL
# Label 2228: http://www.webservicex.com/geoipservice.asmx?WSDL
# Label 2229: http://www.webservicex.com/globalweather.asmx?WSDL
# Label 2230: http://www.webservicex.com/icd10.asmx?WSDL
# Label 2231: http://www.webservicex.com/icd9.asmx?WSDL
# Label 2232: http://www.webservicex.com/icd9drug.asmx?WSDL
# Label 2233: http://www.webservicex.com/icd9toicd10.asmx?WSDL
# Label 2234: http://www.webservicex.com/periodictable.asmx?wsdl
# Label 2235: http://www.webservicex.com/sendsmsworld.asmx?WSDL
# Label 2236: http://www.webservicex.net/AustralianPostCode.asmx?WSDL
# Label 2237: http://www.webservicex.net/ConvertAcceleration.asmx?WSDL
# Label 2238: http://www.webservicex.net/ConvertArea.asmx?WSDL
# Label 2239: http://www.webservicex.net/ConvertEnergy.asmx?WSDL
# Label 2240: http://www.webservicex.net/ConvertTorque.asmx?WSDL
# Label 2241: http://www.webservicex.net/CreditCard.asmx?WSDL
# Label 2242: http://www.webservicex.net/CurrencyConvertor.asmx?wsdl
# Label 2243: http://www.webservicex.net/MortgageIndex.asmx?wsdl
# Label 2244: http://www.webservicex.net/NAICS.asmx?wsdl
# Label 2245: http://www.webservicex.net/RssToHTML.asmx?WSDL
# Label 2246: http://www.webservicex.net/Statistics.asmx?WSDL
# Label 2247: http://www.webservicex.net/UDDIBusinessFinder.asmx?WSDL
# Label 2248: http://www.webservicex.net/ValidateEmail.asmx?WSDL
# Label 2249: http://www.webservicex.net/barcode.asmx?WSDL
# Label 2250: http://www.webservicex.net/bep.asmx?WSDL
# Label 2251: http://www.webservicex.net/cashflow.asmx?WSDL
# Label 2252: http://www.webservicex.net/convertFrequency.asmx?WSDL
# Label 2253: http://www.webservicex.net/icd9toicd10.asmx?WSDL
# Label 2254: http://www.webservicex.net/stockquote.asmx?WSDL
# Label 2255: http://www.webservicex.net/usweather.asmx?WSDL
# Label 2256: http://www.websitepulse.com/wsdl/wsp.wsdl
# Label 2257: http://www.west-wind.com/webstoresandbox/admin/WebStoreAdminService.asmx?WSDL
# Label 2258: http://www.west-wind.com/webstoresandbox/service/WebStoreConsumerService.asmx?WSDL
# Label 2259: http://www.whatdoing.com/WebTools/Tools.asmx?wsdl
# Label 2260: http://www.whitemesa.com/r3/InteropTestDocLit.wsdl
# Label 2261: http://www.whitemesa.com/r3/InteropTestDocLitParameters.wsdl
# Label 2262: http://www.whitemesa.com/r3/InteropTestExtensibility.wsdl
# Label 2263: http://www.whitemesa.com/r3/InteropTestList.wsdl
# Label 2264: http://www.whitemesa.com/r3/compound1.wsdl
# Label 2265: http://www.whitemesa.com/r3/compound2.wsdl
# Label 2266: http://www.whitemesa.com/r3/emptysa.wsdl
# Label 2267: http://www.whitemesa.com/r3/interoptestrpcenc.wsdl
# Label 2268: http://www.whitemesa.net/r3/InteropTestDocLit.wsdl
# Label 2269: http://www.whitemesa.net/r3/InteropTestDocLitParameters.wsdl
# Label 2270: http://www.whitemesa.net/r3/InteropTestExtensibility.wsdl
# Label 2271: http://www.whitemesa.net/r3/InteropTestExtensibilityRequired.wsdl
# Label 2272: http://www.whitemesa.net/r3/InteropTestRpcEnc.wsdl
# Label 2273: http://www.whitemesa.net/r3/InteropTestheaders.wsdl
# Label 2274: http://www.whitemesa.net/r3/compound1.wsdl
# Label 2275: http://www.whitemesa.net/r3/compound2.wsdl
# Label 2276: http://www.whitemesa.net/wsdl/interop.wsdl
# Label 2277: http://www.whitemesa.net/wsdl/interopdoc.wsdl
# Label 2278: http://www.whitemesa.net/wsdl/r4/soapfault.wsdl
# Label 2279: http://www.whitemesa.net/wsdl/soap12-add-test-doc.wsdl
# Label 2280: http://www.whitemesa.net/wsdl/soap12-add-test-int.wsdl
# Label 2281: http://www.whitemesa.net/wsdl/soap12-add-test-rpc.wsdl
# Label 2282: http://www.whitemesa.net/wsdl/wm_ws-rp_end.wsdl
# Label 2283: http://www.whiteyork.com/hostingusage.asmx?wsdl
# Label 2284: http://www.whizspark.com/WebServices/MailingList.asmx?wsdl
# Label 2285: http://www.willamowius.com/KontoCheck.wsdl
# Label 2286: http://www.witsml.org/api/130/WMLP.WSDL
# Label 2287: http://www.witsml.org/api/130/WMLS.WSDL
# Label 2288: http://www.witsml.org/api/131/WMLP.WSDL
# Label 2289: http://www.witsml.org/api/131/WMLS.WSDL
# Label 2290: http://www.witsml.org/api/131d/WMLS.WSDL
# Label 2291: http://www.woodworkingmachineryauction.com/XFService.asmx?wsdl
# Label 2292: http://www.wopos.com/webservice/Rss.asmx?wsdl
# Label 2293: http://www.wopos.com/webservice/Stock.asmx?wsdl
# Label 2294: http://www.wopos.com/webservice/ips.asmx?wsdl
# Label 2295: http://www.worldwildweb.biz/webservices/zipCodeWebService.cfc?wsdl
# Label 2296: http://www.wsindex.org/wsindexLinks.wsdl
# Label 2297: http://www.wssdemo.com/_vti_bin/lists.asmx?wsdl
# Label 2298: http://www.wurzburg.com/UPS/UpsValidation.asmx?wsdl
# Label 2299: http://www.wwv-it.com/DateTimeSpan/ComputeDateTimeSpan.asmx?wsdl
# Label 2300: http://www.wysecommunicator.com/Global/SecureLogin.asmx?wsdl
# Label 2301: http://www.xamlshare.com/editservice.asmx?wsdl
# Label 2302: http://www.xatanet.net/XataNetWebService/xatadispatchwebservice.asmx?WSDL
# Label 2303: http://www.xcshop.com/services/xcshopservice.asmx?wsdl
# Label 2304: http://www.xignite.com/xArchive.asmx?wsdl
# Label 2305: http://www.xignite.com/xChart.asmx?wsdl
# Label 2306: http://www.xignite.com/xDataSet.asmx?wsdl
# Label 2307: http://www.xignite.com/xEmerging.asmx?WSDL
# Label 2308: http://www.xignite.com/xExchanges.asmx?WSDL
# Label 2309: http://www.xignite.com/xFunds.asmx?WSDL
# Label 2310: http://www.xignite.com/xGE.asmx?wsdl
# Label 2311: http://www.xignite.com/xHistorical.asmx?WSDL
# Label 2312: http://www.xignite.com/xInsider.asmx?wsdl
# Label 2313: http://www.xignite.com/xMaster.asmx?wsdl
# Label 2314: http://www.xignite.com/xNote.asmx?wsdl
# Label 2315: http://www.xignite.com/xOFAC.asmx?wsdl
# Label 2316: http://www.xignite.com/xRegistration.asmx?wsdl
# Label 2317: http://www.xignite.com/xSurvey.asmx?wsdl
# Label 2318: http://www.xignite.com/xTools.asmx?wsdl
# Label 2319: http://www.xignite.com/xedgar.asmx?WSDL
# Label 2320: http://www.xignite.com/xholdings.asmx?WSDL
# Label 2321: http://www.xignite.com/xmetals.asmx?WSDL
# Label 2322: http://www.xignite.com/xquotes.asmx?WSDL
# Label 2323: http://www.xignite.com/xrealtime.asmx?WSDL
# Label 2324: http://www.xignite.com/xreleases.asmx?WSDL
# Label 2325: http://www.xignite.com/xsecurity.asmx?WSDL
# Label 2326: http://www.xignite.com/xvwap.asmx?WSDL
# Label 2327: http://www.xmlforasp.net/CodeBank/webservices/ACMECorp/ACMECorp.asmx?wsdl
# Label 2328: http://www.xmlme.com/WSDailyNet.asmx?wsdl
# Label 2329: http://www.xmlme.com/WSDailyXml.asmx?wsdl
# Label 2330: http://www.xmlme.com/WSSportingGoods.asmx?WSDL
# Label 2331: http://www.xmlme.com/WSVideoGames.asmx?WSDL
# Label 2332: http://www.xprogramming.com/webservices/service1.asmx?wsdl
# Label 2333: http://www.yarncountry.com/invsvc/Inventory.asmx?wsdl
# Label 2334: http://www.yataka.com/NSVMCachingAPI/NSVMCachingAPI.asmx?WSDL
# Label 2335: http://www.yazgelistir.com/YGServices/ArticleService.asmx?wsdl
# Label 2336: http://www.zbirka.com/Services/DOCTRACE_SERVICE/InsertRelation.asmx?wsdl
# Label 2337: http://www.zeesource.net/maps/services/Geocode?wsdl
# Label 2338: http://www.zeta-software.de/ZetaSpamChecker/SpamCheckerService.asmx?WSDL
# Label 2339: http://www.zhd.ru/WEBServices/WSRequests.asmx?WSDL
# Label 2340: http://www.zipmgr.com/GeoBrokr.asmx?wsdl
# Label 2341: http://www.zoekteenlief.be/gateway/service.php?wsdl
# Label 2342: http://www10.brinkster.com/jochenh/hotmail.asmx?WSDL
# Label 2343: http://www17.brinkster.com/imneo/timesvc.asmx?wsdl
# Label 2344: http://www2.websitepulse.com/wsdl/wsp.wsdl
# Label 2345: http://www22.brinkster.com/horaciovallejo/netpress1.asmx?wsdl
# Label 2346: http://www28.brinkster.com/krhtraining/HelloWorld.asmx?wsdl
# Label 2347: http://xaraya.open-world.com.ve/modules/soapserver/xaraya.wsdl
# Label 2348: http://xaraya.open-world.com.ve/ws.php?wsdl
# Label 2349: http://xform.metaverse.cc/xformservice.asmx?wsdl
# Label 2350: http://xgatetest.thevisp.co.uk/Webservice/Services/Order.asmx?wsdl
# Label 2351: http://xignite.com/xInsider.asmx?wsdl
# Label 2352: http://xignite.com/xNews.asmx?wsdl
# Label 2353: http://xignite10.xignite.com/xChart.asmx?wsdl
# Label 2354: http://xignite10.xignite.com/xRealTime.asmx?wsdl
# Label 2355: http://xignite19.xignite.com/xTools.asmx?wsdl
# Label 2356: http://xml.2buypcs.com/services/pcsdealers.asmx?WSDL
# Label 2357: http://xml.afpc.tamu.edu/StockQuoteService.wsdl
# Label 2358: http://xml.assessment.com/service/MAPPMatching.asmx?wsdl
# Label 2359: http://xml.assessment.com/service/MAPPResults.asmx?wsdl
# Label 2360: http://xml.nig.ac.jp/wsdl/ARSA.wsdl
# Label 2361: http://xml.nig.ac.jp/wsdl/Blast.wsdl
# Label 2362: http://xml.nig.ac.jp/wsdl/BlastDemo.wsdl
# Label 2363: http://xml.nig.ac.jp/wsdl/DDBJ.wsdl
# Label 2364: http://xml.nig.ac.jp/wsdl/Ensembl.wsdl
# Label 2365: http://xml.nig.ac.jp/wsdl/Fasta.wsdl
# Label 2366: http://xml.nig.ac.jp/wsdl/Gtop.wsdl
# Label 2367: http://xml.nig.ac.jp/wsdl/Mapping.wsdl
# Label 2368: http://xml.nig.ac.jp/wsdl/OMIM.wsdl
# Label 2369: http://xml.nig.ac.jp/wsdl/PML.wsdl
# Label 2370: http://xml.nig.ac.jp/wsdl/RefSeq.wsdl
# Label 2371: http://xml.nig.ac.jp/wsdl/SPS.wsdl
# Label 2372: http://xml.nig.ac.jp/wsdl/SRS.wsdl
# Label 2373: http://xml.worldstartel.it:8080/ws/wsdl/DisponibilitaOutsourcerSoap.wsdl
# Label 2374: http://xmlme.com/WSCustNews.asmx?WSDL
# Label 2375: http://xmltools.oio.dk/afstd/afstandsberegner.asmx?WSDL
# Label 2376: http://yorktown.cbe.wwu.edu/04Fall/hawleyr/A2/CreditCardValidate.asmx?wsdl
# Label 2377: http://yvesk3.dotnet3.hostbasket.com/dasBlog/SyndicationServiceExperimental.asmx?wsdl
# Label 2378: http://zeta-software.de/Uploader/Communication.asmx?wsdl
# =====================

# %%
# dataframe
df
# Out:
#       Response Time  Availability  Throughput  Successability  Reliability  \
# 0            302.75            89         7.1              90           73
# 1            482.00            85        16.0              95           73
# 2           3321.40            89         1.4              96           73
# 3            126.17            98        12.0             100           67
# 4            107.00            87         1.9              95           73
# ...             ...           ...         ...             ...          ...
# 2498         200.80            93         2.4              98           73
# 2499          56.17            97        11.3              97           83
# 2500          93.93            80         2.1              80           67
# 2501         106.75            86         1.3              95           80
# 2502         316.50            72        15.9              72           80
#
#       Compliance  Best Practices  Latency  Documentation  Service Name  \
# 0             78              80   187.75             32           609
# 1            100              84     1.00              2           181
# 2             78              80     2.60             96          1087
# 3             78              82    22.77             89           389
# 4             89              62    58.33             93           154
# ...          ...             ...      ...            ...           ...
# 2498         100              84     7.40             41          1391
# 2499          78              91     7.17              3            18
# 2500          78              82     3.72             60          1420
# 2501          78              87     1.25             96           891
# 2502          89              87     5.50              8           977
#
#       WSDL Address
# 0             2358
# 1             1864
# 2             2112
# 3             1733
# 4              242
# ...            ...
# 2498           295
# 2499            75
# 2500          1290
# 2501           637
# 2502           891
#
# [2503 rows x 11 columns]

# %% [markdown]
# #### Build Recommendation system model

# %%
import pandas as pd
from sklearn.preprocessing import MinMaxScaler
from sklearn.neighbors import NearestNeighbors
import joblib

# Features for the recommendation
features = ['Response Time', 'Availability', 'Throughput', 'Successability', 
            'Reliability', 'Compliance', 'Best Practices', 'Latency', 'Documentation']

# Step 1: Normalize features
scaler = MinMaxScaler()
df[features] = scaler.fit_transform(df[features])

# Step 2: Train k-Nearest Neighbors model
knn_model = NearestNeighbors(n_neighbors=10, metric='euclidean')
knn_model.fit(df[features])

# Step 3: Save both the model and the scaler
joblib.dump(knn_model, r'models\knn_recommender_model.joblib')
joblib.dump(scaler, r'modelsscaler.joblib')
# Out:
# ['modelsscaler.joblib']

# %%
import joblib
import numpy as np
import pandas as pd

# Load the trained model and scaler and dataset
knn_model = joblib.load(r'models\knn_recommender_model.joblib')
scaler = joblib.load(r'models\scaler.joblib')
data = pd.read_csv(r"dataset\Final_data.csv")

def recommendations(input):
    # Step 1: Scale the user input
    user_input_scaled = scaler.transform([input])

    # Step 2: Get the 10 nearest neighbors
    distances, indices = knn_model.kneighbors(user_input_scaled)
    print("distances:", distances)
    print("indices:", indices)

    # Step 3: Retrieve the recommended WSDL Addresses
    for idx in indices[0]:  # Loop over the first row of the indices array
        url = data.iloc[idx]['WSDL Address']  # Get the WSDL Address for each index
        print(idx, " => ", url)
# Out:
# c:\Users\0877\.conda\envs\tk161562\lib\site-packages\sklearn\base.py:348: InconsistentVersionWarning: Trying to unpickle estimator MinMaxScaler from version 1.1.3 when using version 1.3.2. This might lead to breaking code or invalid results. Use at your own risk. For more info please refer to:
# https://scikit-learn.org/stable/model_persistence.html#security-maintainability-limitations
#   warnings.warn(

# %%
# example input (index 0)
recommendations([302.75, 89, 7.1, 90, 73, 78, 80, 187.75, 32])
# Out:
# distances: [[0.         0.12303584 0.12327288 0.12436351 0.13526677 0.14221896
#   0.14610035 0.14718515 0.15256321 0.15333333]]
# indices: [[   0 1968  429  698 1318 2408 2336 1165 1145 1778]]
# 0  =>  http://xml.assessment.com/service/MAPPMatching.asmx?wsdl
# 1968  =>  http://www.xmlme.com/WSDailyXml.asmx?wsdl
# 429  =>  http://ws.cdyne.com/ziptogeo/zip2geo.asmx?wsdl
# 698  =>  http://xml.assessment.com/service/MAPPResults.asmx?wsdl
# 1318  =>  http://www.xmlme.com/WSDailyNet.asmx?wsdl
# 2408  =>  http://scores.serviceobjects.com/CupScores.asmx?WSDL
# 2336  =>  http://www.xmlme.com/WSSportingGoods.asmx?WSDL
# 1165  =>  http://www.webservicex.com/globalweather.asmx?WSDL
# 1145  =>  http://www.webservicex.net/UDDIBusinessFinder.asmx?WSDL
# 1778  =>  http://interlockingapplications.com/gs/wsDice.asmx?wsdl
# c:\Users\0877\.conda\envs\tk161562\lib\site-packages\sklearn\base.py:465: UserWarning: X does not have valid feature names, but MinMaxScaler was fitted with feature names
#   warnings.warn(
# c:\Users\0877\.conda\envs\tk161562\lib\site-packages\sklearn\base.py:465: UserWarning: X does not have valid feature names, but NearestNeighbors was fitted with feature names
#   warnings.warn(

# %%
# example input (index 2502)
recommendations([316.5, 72, 15.9, 72, 80, 89, 87, 5.5, 8])
# Out:
# distances: [[0.         0.06637653 0.07244216 0.07469639 0.08476595 0.08662802
#   0.10154039 0.11371418 0.11584924 0.11809573]]
# indices: [[2502  495  972  801  508 1277  822  420   79  478]]
# 2502  =>  http://use.perl.org/soap/Test.wsdl
# 495  =>  http://www.ebob42.com/cgi-bin/Romulan.exe/wsdl/IRoman
# 972  =>  http://oscar.snapps.com/portal.nsf/PlaceCatalog?WSDL
# 801  =>  http://developerdays.com/cgi-bin/tempconverter.exe/wsdl/ITempConverter?WSDL
# 508  =>  http://www.sandrini-a.com/ws/sandrini.wsdl
# 1277  =>  http://oscar.snapps.com/Portal.nsf/Echo?wsdl
# 822  =>  http://oscar.snapps.com/portal.nsf/MyService?WSDL
# 420  =>  http://email.secureserver.net/vsdbServer.php?wsdl
# 79  =>  http://sas-d.sermepa.es/TPV_PC/wsdl/SerClsEntradaTPVPCv3d0.wsdl
# 478  =>  http://tomcatbackup.esat.kuleuven.be/maran/Maran.wsdl
# c:\Users\0877\.conda\envs\tk161562\lib\site-packages\sklearn\base.py:465: UserWarning: X does not have valid feature names, but MinMaxScaler was fitted with feature names
#   warnings.warn(
# c:\Users\0877\.conda\envs\tk161562\lib\site-packages\sklearn\base.py:465: UserWarning: X does not have valid feature names, but NearestNeighbors was fitted with feature names
#   warnings.warn(

# %%
# example input (index 684)
recommendations([219, 87, 2.8, 96, 73, 78, 80, 17, 87, ])
# Out:
# distances: [[0.         0.06413985 0.07156172 0.08282155 0.08647759 0.08676694
#   0.096541   0.09762119 0.0980833  0.10184511]]
# indices: [[ 684   19 1730 2190 2251   91 1799 1692 1249 1227]]
# 684  =>  http://ws.keyfortravel.com/Hotel/hotelavail.asmx?wsdl
# 19  =>  http://trial.serviceobjects.com/fpl/FraudProtectionLite.asmx?WSDL
# 1730  =>  http://ws2.serviceobjects.net/pa/phoneappend.asmx?wsdl
# 2190  =>  http://www.gecip.net/SMSWS/sms.asmx?wsdl
# 2251  =>  http://ws.interfax.net/inbound.asmx?wsdl
# 91  =>  http://mackeybros.com/WebServices/UPSRates.asmx?wsdl
# 1799  =>  http://gisdata.usgs.net/XMLWebServices/USNG.asmx?WSDL
# 1692  =>  http://ws.keyfortravel.com/webservices/K4THotelSell.asmx?wsdl
# 1249  =>  http://www.fullerdata.com/FortuneCookie/FortuneCookie.asmx?WSDL
# 1227  =>  http://www.insuma.de/wsdl/demo.wsdl
# c:\Users\0877\.conda\envs\tk161562\lib\site-packages\sklearn\base.py:465: UserWarning: X does not have valid feature names, but MinMaxScaler was fitted with feature names
#   warnings.warn(
# c:\Users\0877\.conda\envs\tk161562\lib\site-packages\sklearn\base.py:465: UserWarning: X does not have valid feature names, but NearestNeighbors was fitted with feature names
#   warnings.warn(
